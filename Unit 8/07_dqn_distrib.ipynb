# %%
import gym
import ptan
import random
import numpy as np

import torch
import torch.optim as optim
import torch.nn.functional as F

from ignite.engine import Engine

from lib import common, dqn_extra

NAME = "07_distrib"

# %%
def calc_loss(batch, net, tgt_net, gamma, device="cpu"):
    states, actions, rewards, dones, next_states = \
        common.unpack_batch(batch)
    batch_size = len(batch)

    states_v = torch.tensor(states).to(device)
    actions_v = torch.tensor(actions).to(device)
    next_states_v = torch.tensor(next_states).to(device)

    # next state distribution
    next_distr_v, next_qvals_v = tgt_net.both(next_states_v)
    next_acts = next_qvals_v.max(1)[1].data.cpu().numpy()
    next_distr = tgt_net.apply_softmax(next_distr_v)
    next_distr = next_distr.data.cpu().numpy()

    next_best_distr = next_distr[range(batch_size), next_acts]
    dones = dones.astype(np.bool)

    proj_distr = dqn_extra.distr_projection(
        next_best_distr, rewards, dones, gamma)

    distr_v = net(states_v)
    sa_vals = distr_v[range(batch_size), actions_v.data]
    state_log_sm_v = F.log_softmax(sa_vals, dim=1)
    proj_distr_v = torch.tensor(proj_distr).to(device)

    loss_v = -state_log_sm_v * proj_distr_v
    return loss_v.sum(dim=1).mean()

# %%
random.seed(common.SEED)
torch.manual_seed(common.SEED)
params = common.HYPERPARAMS['pong']
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

env = gym.make("PongNoFrameskip-v4")
env = ptan.common.wrappers.wrap_dqn(env)
env.seed(common.SEED)
# Out:
# [123, 151010689]

# %%
net = dqn_extra.DistributionalDQN(env.observation_space.shape, env.action_space.n).to(device)
print(net)
tgt_net = ptan.agent.TargetNet(net)
selector = ptan.actions.EpsilonGreedyActionSelector(epsilon=params.epsilon_start)
epsilon_tracker = common.EpsilonTracker(selector, params)
agent = ptan.agent.DQNAgent(lambda x: net.qvals(x), selector, device = device)

exp_source = ptan.experience.ExperienceSourceFirstLast(
    env, agent, gamma=params.gamma)
buffer = ptan.experience.ExperienceReplayBuffer(
    exp_source, buffer_size=params.replay_size)
optimizer = optim.Adam(net.parameters(), lr=params.learning_rate)
# Out:
# DistributionalDQN(
#   (conv): Sequential(
#     (0): Conv2d(4, 32, kernel_size=(8, 8), stride=(4, 4))
#     (1): ReLU()
#     (2): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2))
#     (3): ReLU()
#     (4): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1))
#     (5): ReLU()
#   )
#   (fc): Sequential(
#     (0): Linear(in_features=3136, out_features=512, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=512, out_features=306, bias=True)
#   )
#   (softmax): Softmax(dim=1)
# )

# %%
def process_batch(engine, batch):
    optimizer.zero_grad()
    loss_v = calc_loss(batch, net, tgt_net.target_model,
                       gamma=params.gamma, device=device)
    loss_v.backward()
    optimizer.step()
    epsilon_tracker.frame(engine.state.iteration)
    if engine.state.iteration % params.target_net_sync == 0:
        tgt_net.sync()

    return {
        "loss": loss_v.item(),
        "epsilon": selector.epsilon,
    }

engine = Engine(process_batch)
common.setup_ignite(engine, params, exp_source, NAME)
engine.run(common.batch_generator(buffer, params.replay_initial, params.batch_size))
# Out:
# Episode 1: reward=-21, steps=840, speed=0.0 f/s, elapsed=0:01:12
# Episode 2: reward=-21, steps=912, speed=0.0 f/s, elapsed=0:01:12
# Episode 3: reward=-21, steps=955, speed=0.0 f/s, elapsed=0:01:12
# Episode 4: reward=-21, steps=757, speed=0.0 f/s, elapsed=0:01:12
# Episode 5: reward=-21, steps=903, speed=0.0 f/s, elapsed=0:01:12
# Episode 6: reward=-20, steps=1033, speed=0.0 f/s, elapsed=0:01:12
# Episode 7: reward=-20, steps=1030, speed=0.0 f/s, elapsed=0:01:12
# Episode 8: reward=-20, steps=864, speed=0.0 f/s, elapsed=0:01:12
# Episode 9: reward=-20, steps=987, speed=0.0 f/s, elapsed=0:01:12
# Episode 10: reward=-21, steps=869, speed=0.0 f/s, elapsed=0:01:12
# Episode 11: reward=-20, steps=972, speed=45.2 f/s, elapsed=0:01:15
# Episode 12: reward=-21, steps=814, speed=45.3 f/s, elapsed=0:01:30
# Episode 13: reward=-20, steps=1161, speed=45.5 f/s, elapsed=0:01:53
# Episode 14: reward=-21, steps=984, speed=45.6 f/s, elapsed=0:02:12
# Episode 15: reward=-20, steps=840, speed=45.7 f/s, elapsed=0:02:28
# Episode 16: reward=-20, steps=891, speed=45.8 f/s, elapsed=0:02:46
# Episode 17: reward=-21, steps=758, speed=45.9 f/s, elapsed=0:03:01
# Episode 18: reward=-20, steps=1011, speed=46.0 f/s, elapsed=0:03:20
# Episode 19: reward=-20, steps=938, speed=46.1 f/s, elapsed=0:03:38
# Episode 20: reward=-21, steps=989, speed=46.3 f/s, elapsed=0:03:57
# Episode 21: reward=-19, steps=1045, speed=46.4 f/s, elapsed=0:04:18
# Episode 22: reward=-20, steps=867, speed=46.5 f/s, elapsed=0:04:34
# Episode 23: reward=-21, steps=899, speed=46.6 f/s, elapsed=0:04:52
# Episode 24: reward=-20, steps=927, speed=46.7 f/s, elapsed=0:05:10
# Episode 25: reward=-19, steps=1227, speed=46.8 f/s, elapsed=0:05:34
# Episode 26: reward=-20, steps=977, speed=46.9 f/s, elapsed=0:05:53
# Episode 27: reward=-21, steps=855, speed=47.0 f/s, elapsed=0:06:09
# Episode 28: reward=-20, steps=978, speed=47.1 f/s, elapsed=0:06:28
# Episode 29: reward=-20, steps=957, speed=47.1 f/s, elapsed=0:06:46
# Episode 30: reward=-21, steps=986, speed=47.2 f/s, elapsed=0:07:06
# Episode 31: reward=-19, steps=1056, speed=47.3 f/s, elapsed=0:07:26
# Episode 32: reward=-20, steps=1066, speed=47.4 f/s, elapsed=0:07:47
# Episode 33: reward=-20, steps=988, speed=47.5 f/s, elapsed=0:08:06
# Episode 34: reward=-19, steps=1101, speed=47.6 f/s, elapsed=0:08:27
# Episode 35: reward=-20, steps=1015, speed=47.7 f/s, elapsed=0:08:47
# Episode 36: reward=-21, steps=938, speed=47.7 f/s, elapsed=0:09:05
# Episode 37: reward=-21, steps=876, speed=47.9 f/s, elapsed=0:09:21
# Episode 38: reward=-21, steps=879, speed=47.9 f/s, elapsed=0:09:39
# Episode 39: reward=-21, steps=908, speed=47.9 f/s, elapsed=0:09:57
# Episode 40: reward=-21, steps=790, speed=47.9 f/s, elapsed=0:10:14
# Episode 41: reward=-20, steps=893, speed=47.9 f/s, elapsed=0:10:32
# Episode 42: reward=-20, steps=839, speed=48.0 f/s, elapsed=0:10:49
# Episode 43: reward=-20, steps=1195, speed=48.0 f/s, elapsed=0:11:13
# Episode 44: reward=-21, steps=881, speed=48.0 f/s, elapsed=0:11:31
# Episode 45: reward=-21, steps=818, speed=48.0 f/s, elapsed=0:11:48
# Episode 46: reward=-19, steps=1015, speed=48.0 f/s, elapsed=0:12:09
# Episode 47: reward=-21, steps=898, speed=48.0 f/s, elapsed=0:12:28
# Episode 48: reward=-20, steps=1028, speed=48.1 f/s, elapsed=0:12:49
# Episode 49: reward=-21, steps=898, speed=48.1 f/s, elapsed=0:13:08
# Episode 50: reward=-21, steps=901, speed=48.1 f/s, elapsed=0:13:26
# Episode 51: reward=-20, steps=900, speed=48.1 f/s, elapsed=0:13:44
# Episode 52: reward=-19, steps=971, speed=48.1 f/s, elapsed=0:14:05
# Episode 53: reward=-21, steps=905, speed=48.1 f/s, elapsed=0:14:23
# Episode 54: reward=-21, steps=929, speed=48.2 f/s, elapsed=0:14:41
# Episode 55: reward=-21, steps=972, speed=48.3 f/s, elapsed=0:14:59
# Episode 56: reward=-21, steps=875, speed=48.3 f/s, elapsed=0:15:17
# Episode 57: reward=-19, steps=1060, speed=48.4 f/s, elapsed=0:15:37
# Episode 58: reward=-21, steps=957, speed=48.4 f/s, elapsed=0:15:56
# Episode 59: reward=-20, steps=977, speed=48.5 f/s, elapsed=0:16:15
# Episode 60: reward=-21, steps=840, speed=48.6 f/s, elapsed=0:16:31
# Episode 61: reward=-21, steps=846, speed=48.6 f/s, elapsed=0:16:48
# Episode 62: reward=-19, steps=1055, speed=48.7 f/s, elapsed=0:17:08
# Episode 63: reward=-20, steps=944, speed=48.7 f/s, elapsed=0:17:27
# Episode 64: reward=-21, steps=937, speed=48.8 f/s, elapsed=0:17:45
# Episode 65: reward=-21, steps=1002, speed=48.8 f/s, elapsed=0:18:04
# Episode 66: reward=-20, steps=922, speed=48.9 f/s, elapsed=0:18:22
# Episode 67: reward=-20, steps=959, speed=48.9 f/s, elapsed=0:18:41
# Episode 68: reward=-21, steps=897, speed=48.9 f/s, elapsed=0:18:59
# Episode 69: reward=-20, steps=952, speed=49.0 f/s, elapsed=0:19:17
# Episode 70: reward=-21, steps=838, speed=49.1 f/s, elapsed=0:19:34
# Episode 71: reward=-21, steps=1032, speed=49.1 f/s, elapsed=0:19:54
# Episode 72: reward=-20, steps=1246, speed=49.1 f/s, elapsed=0:20:19
# Episode 73: reward=-21, steps=958, speed=49.2 f/s, elapsed=0:20:37
# Episode 74: reward=-21, steps=820, speed=49.2 f/s, elapsed=0:20:54
# Episode 75: reward=-20, steps=924, speed=49.2 f/s, elapsed=0:21:12
# Episode 76: reward=-21, steps=938, speed=49.2 f/s, elapsed=0:21:30
# Episode 77: reward=-20, steps=1074, speed=49.3 f/s, elapsed=0:21:52
# Episode 78: reward=-21, steps=880, speed=49.3 f/s, elapsed=0:22:09
# Episode 79: reward=-19, steps=973, speed=49.3 f/s, elapsed=0:22:28
# Episode 80: reward=-20, steps=1010, speed=49.4 f/s, elapsed=0:22:48
# Episode 81: reward=-21, steps=942, speed=49.4 f/s, elapsed=0:23:06
# Episode 82: reward=-21, steps=1150, speed=49.4 f/s, elapsed=0:23:29
# Episode 83: reward=-21, steps=877, speed=49.5 f/s, elapsed=0:23:46
# Episode 84: reward=-21, steps=941, speed=49.5 f/s, elapsed=0:24:04
# Episode 85: reward=-21, steps=897, speed=49.5 f/s, elapsed=0:24:22
# Episode 86: reward=-20, steps=1006, speed=49.5 f/s, elapsed=0:24:42
# Episode 87: reward=-21, steps=1069, speed=49.6 f/s, elapsed=0:25:03
# Episode 88: reward=-20, steps=917, speed=49.6 f/s, elapsed=0:25:21
# Episode 89: reward=-21, steps=884, speed=49.6 f/s, elapsed=0:25:38
# Episode 90: reward=-21, steps=937, speed=49.6 f/s, elapsed=0:25:57
# Episode 91: reward=-21, steps=804, speed=49.7 f/s, elapsed=0:26:13
# Episode 92: reward=-20, steps=909, speed=49.7 f/s, elapsed=0:26:30
# Episode 93: reward=-21, steps=1012, speed=49.7 f/s, elapsed=0:26:50
# Episode 94: reward=-20, steps=1080, speed=49.7 f/s, elapsed=0:27:12
# Episode 95: reward=-21, steps=819, speed=49.8 f/s, elapsed=0:27:27
# Episode 96: reward=-21, steps=837, speed=50.0 f/s, elapsed=0:27:42
# Episode 97: reward=-20, steps=832, speed=50.1 f/s, elapsed=0:27:56
# Episode 98: reward=-20, steps=960, speed=50.3 f/s, elapsed=0:28:13
# Episode 99: reward=-20, steps=979, speed=50.4 f/s, elapsed=0:28:30
# Episode 100: reward=-21, steps=939, speed=50.6 f/s, elapsed=0:28:46
# Episode 101: reward=-21, steps=985, speed=50.7 f/s, elapsed=0:29:03
# Episode 102: reward=-20, steps=1073, speed=50.8 f/s, elapsed=0:29:22
# Episode 103: reward=-20, steps=1127, speed=50.8 f/s, elapsed=0:29:45
# Episode 104: reward=-21, steps=947, speed=50.8 f/s, elapsed=0:30:04
# Episode 105: reward=-21, steps=1112, speed=50.8 f/s, elapsed=0:30:26
# Episode 106: reward=-20, steps=1327, speed=50.9 f/s, elapsed=0:30:49
# Episode 107: reward=-21, steps=820, speed=51.1 f/s, elapsed=0:31:03
# Episode 108: reward=-20, steps=1017, speed=51.2 f/s, elapsed=0:31:20
# Episode 109: reward=-20, steps=1118, speed=51.3 f/s, elapsed=0:31:39
# Episode 110: reward=-20, steps=959, speed=51.5 f/s, elapsed=0:31:56
# Episode 111: reward=-20, steps=1029, speed=51.6 f/s, elapsed=0:32:14
# Episode 112: reward=-20, steps=830, speed=51.7 f/s, elapsed=0:32:28
# Episode 113: reward=-19, steps=993, speed=51.9 f/s, elapsed=0:32:45
# Episode 114: reward=-21, steps=857, speed=52.0 f/s, elapsed=0:33:00
# Episode 115: reward=-18, steps=1347, speed=52.1 f/s, elapsed=0:33:23
# Episode 116: reward=-18, steps=1310, speed=52.2 f/s, elapsed=0:33:46
# Episode 117: reward=-20, steps=1013, speed=52.3 f/s, elapsed=0:34:04
# Episode 118: reward=-20, steps=1173, speed=52.4 f/s, elapsed=0:34:24
# Episode 119: reward=-19, steps=1295, speed=52.5 f/s, elapsed=0:34:46
# Episode 120: reward=-19, steps=1222, speed=52.6 f/s, elapsed=0:35:07
# Episode 121: reward=-19, steps=1299, speed=52.8 f/s, elapsed=0:35:29
# Episode 122: reward=-19, steps=1297, speed=52.9 f/s, elapsed=0:35:51
# Episode 123: reward=-18, steps=1759, speed=53.0 f/s, elapsed=0:36:22
# Episode 124: reward=-21, steps=1095, speed=53.1 f/s, elapsed=0:36:40
# Episode 125: reward=-21, steps=1168, speed=53.2 f/s, elapsed=0:37:00
# Episode 126: reward=-16, steps=1535, speed=53.3 f/s, elapsed=0:37:27
# Episode 127: reward=-17, steps=1585, speed=53.4 f/s, elapsed=0:37:54
# Episode 128: reward=-20, steps=1382, speed=53.5 f/s, elapsed=0:38:18
# Episode 129: reward=-17, steps=1595, speed=53.6 f/s, elapsed=0:38:45
# Episode 130: reward=-14, steps=1643, speed=53.7 f/s, elapsed=0:39:13
# Episode 131: reward=-18, steps=1597, speed=53.8 f/s, elapsed=0:39:40
# Episode 132: reward=-17, steps=1566, speed=53.9 f/s, elapsed=0:40:07
# Episode 133: reward=-17, steps=1847, speed=54.0 f/s, elapsed=0:40:39
# Episode 134: reward=-14, steps=1631, speed=54.1 f/s, elapsed=0:41:07
# Episode 135: reward=-17, steps=1710, speed=54.2 f/s, elapsed=0:41:36
# Episode 136: reward=-20, steps=1226, speed=54.2 f/s, elapsed=0:41:57
# Episode 137: reward=-21, steps=1126, speed=54.3 f/s, elapsed=0:42:16
# Episode 138: reward=-20, steps=1216, speed=54.4 f/s, elapsed=0:42:37
# Episode 139: reward=-17, steps=1600, speed=54.4 f/s, elapsed=0:43:05
# Episode 140: reward=-19, steps=1268, speed=54.5 f/s, elapsed=0:43:27
# Episode 141: reward=-16, steps=1498, speed=54.6 f/s, elapsed=0:43:53
# Episode 142: reward=-11, steps=2126, speed=54.7 f/s, elapsed=0:44:29
# Episode 143: reward=-16, steps=1582, speed=54.7 f/s, elapsed=0:44:57
# Episode 144: reward=-15, steps=1612, speed=54.8 f/s, elapsed=0:45:24
# Episode 145: reward=-14, steps=1833, speed=54.9 f/s, elapsed=0:45:56
# Episode 146: reward=-17, steps=1533, speed=54.9 f/s, elapsed=0:46:22
# Episode 147: reward=-14, steps=2005, speed=54.9 f/s, elapsed=0:46:58
# Episode 148: reward=-11, steps=2085, speed=54.8 f/s, elapsed=0:47:41
# Episode 149: reward=-16, steps=1701, speed=54.7 f/s, elapsed=0:48:15
# Episode 150: reward=-15, steps=1775, speed=54.6 f/s, elapsed=0:48:50
# Episode 151: reward=-18, steps=1433, speed=54.6 f/s, elapsed=0:49:18
# Episode 152: reward=-16, steps=1791, speed=54.5 f/s, elapsed=0:49:55
# Episode 153: reward=-14, steps=1721, speed=54.4 f/s, elapsed=0:50:29
# Episode 154: reward=-17, steps=1595, speed=54.3 f/s, elapsed=0:51:01
# Episode 155: reward=-16, steps=1759, speed=54.2 f/s, elapsed=0:51:36
# Episode 156: reward=-16, steps=1698, speed=54.1 f/s, elapsed=0:52:10
# Episode 157: reward=-16, steps=1739, speed=54.0 f/s, elapsed=0:52:45
# Episode 158: reward=-18, steps=1576, speed=54.0 f/s, elapsed=0:53:16
# Episode 159: reward=-14, steps=1833, speed=53.9 f/s, elapsed=0:53:52
# Episode 160: reward=-15, steps=1807, speed=53.8 f/s, elapsed=0:54:28
# Episode 161: reward=-10, steps=2303, speed=53.7 f/s, elapsed=0:55:14
# Episode 162: reward=-17, steps=1758, speed=53.7 f/s, elapsed=0:55:49
# Episode 163: reward=-17, steps=1707, speed=53.6 f/s, elapsed=0:56:23
# Episode 164: reward=-16, steps=1910, speed=53.5 f/s, elapsed=0:57:01
# Episode 165: reward=-16, steps=2084, speed=53.5 f/s, elapsed=0:57:42
# Episode 166: reward=-15, steps=2039, speed=53.4 f/s, elapsed=0:58:22
# Episode 167: reward=-17, steps=1887, speed=53.5 f/s, elapsed=0:58:57
# Episode 168: reward=-13, steps=2093, speed=53.5 f/s, elapsed=0:59:36
# Episode 169: reward=-13, steps=2271, speed=53.5 f/s, elapsed=1:00:17
# Episode 170: reward=-17, steps=1683, speed=53.5 f/s, elapsed=1:00:48
# Episode 171: reward=-11, steps=2988, speed=53.6 f/s, elapsed=1:01:41
# Episode 172: reward=-14, steps=2229, speed=53.6 f/s, elapsed=1:02:20
# Episode 173: reward=-12, steps=2927, speed=53.6 f/s, elapsed=1:03:16
# Episode 174: reward=-11, steps=2667, speed=53.5 f/s, elapsed=1:04:09
# Episode 175: reward=-12, steps=2617, speed=53.5 f/s, elapsed=1:05:02
# Episode 176: reward=-11, steps=2903, speed=53.4 f/s, elapsed=1:06:00
# Episode 177: reward=-15, steps=2002, speed=53.3 f/s, elapsed=1:06:41
# Episode 178: reward=-8, steps=2776, speed=53.1 f/s, elapsed=1:07:42
# Episode 179: reward=-19, steps=1582, speed=52.9 f/s, elapsed=1:08:20
# Episode 180: reward=-13, steps=2331, speed=52.7 f/s, elapsed=1:09:15
# Episode 181: reward=-10, steps=2925, speed=52.5 f/s, elapsed=1:10:25
# Episode 182: reward=-11, steps=2734, speed=52.2 f/s, elapsed=1:11:33
# Episode 183: reward=-16, steps=2169, speed=52.0 f/s, elapsed=1:12:28
# Episode 184: reward=-16, steps=1795, speed=51.7 f/s, elapsed=1:13:14
# Episode 185: reward=-14, steps=2015, speed=51.5 f/s, elapsed=1:14:06
# Episode 186: reward=-10, steps=2748, speed=51.2 f/s, elapsed=1:15:17
# Episode 187: reward=-9, steps=2668, speed=51.0 f/s, elapsed=1:16:25
# Episode 188: reward=-11, steps=2728, speed=50.7 f/s, elapsed=1:17:35
# Episode 189: reward=-15, steps=2554, speed=50.5 f/s, elapsed=1:18:40
# Episode 190: reward=-15, steps=2283, speed=50.3 f/s, elapsed=1:19:37
# Episode 191: reward=-10, steps=2981, speed=50.2 f/s, elapsed=1:20:43
# Episode 192: reward=-16, steps=2323, speed=50.1 f/s, elapsed=1:21:35
# Episode 193: reward=-13, steps=2550, speed=49.9 f/s, elapsed=1:22:40
# Episode 194: reward=-10, steps=2798, speed=49.7 f/s, elapsed=1:23:49
# Episode 195: reward=-11, steps=2807, speed=49.5 f/s, elapsed=1:24:58
# Episode 196: reward=-10, steps=2905, speed=49.3 f/s, elapsed=1:26:10
# Episode 197: reward=-12, steps=2423, speed=49.1 f/s, elapsed=1:27:10
# Episode 198: reward=-11, steps=2606, speed=49.0 f/s, elapsed=1:28:15
# Episode 199: reward=-11, steps=3178, speed=48.8 f/s, elapsed=1:29:33
# Episode 200: reward=-4, steps=3761, speed=48.6 f/s, elapsed=1:31:05
# Episode 201: reward=-10, steps=3075, speed=48.5 f/s, elapsed=1:32:21
# Episode 202: reward=-12, steps=2607, speed=48.3 f/s, elapsed=1:33:25
# Episode 203: reward=-13, steps=2586, speed=48.2 f/s, elapsed=1:34:28
# Episode 204: reward=-8, steps=3141, speed=48.0 f/s, elapsed=1:35:45
# Episode 205: reward=-12, steps=2578, speed=47.9 f/s, elapsed=1:36:45
# Episode 206: reward=-13, steps=2114, speed=47.9 f/s, elapsed=1:37:32
# Episode 207: reward=-12, steps=2649, speed=47.7 f/s, elapsed=1:38:39
# Episode 208: reward=-10, steps=3069, speed=47.5 f/s, elapsed=1:39:56
# Episode 209: reward=-7, steps=3616, speed=47.3 f/s, elapsed=1:41:37
# Episode 210: reward=-13, steps=2369, speed=47.1 f/s, elapsed=1:42:43
# Episode 211: reward=-10, steps=3131, speed=46.8 f/s, elapsed=1:44:14
# Episode 212: reward=-11, steps=2600, speed=46.6 f/s, elapsed=1:45:23
# Episode 213: reward=-14, steps=2644, speed=46.5 f/s, elapsed=1:46:32
# Episode 214: reward=-12, steps=3142, speed=46.3 f/s, elapsed=1:47:53
# Episode 215: reward=-8, steps=3403, speed=46.2 f/s, elapsed=1:49:21
# Episode 216: reward=-9, steps=3200, speed=46.0 f/s, elapsed=1:50:45
# Episode 217: reward=-3, steps=4481, speed=45.9 f/s, elapsed=1:52:41
# Episode 218: reward=-14, steps=2939, speed=45.7 f/s, elapsed=1:53:56
# Episode 219: reward=-7, steps=3368, speed=45.6 f/s, elapsed=1:55:23
# Episode 220: reward=-12, steps=3374, speed=45.5 f/s, elapsed=1:56:49
# Episode 221: reward=-13, steps=2466, speed=45.3 f/s, elapsed=1:57:53
# Episode 222: reward=-8, steps=4352, speed=45.2 f/s, elapsed=1:59:44
# Episode 223: reward=-10, steps=3552, speed=45.1 f/s, elapsed=2:01:15
# Episode 224: reward=-4, steps=3506, speed=45.0 f/s, elapsed=2:02:44
# Episode 225: reward=-13, steps=2781, speed=44.8 f/s, elapsed=2:03:56
# Episode 226: reward=-8, steps=3399, speed=44.7 f/s, elapsed=2:05:23
# Episode 227: reward=-16, steps=2286, speed=44.6 f/s, elapsed=2:06:21
# Episode 228: reward=-16, steps=2259, speed=44.5 f/s, elapsed=2:07:19
# Episode 229: reward=-17, steps=2458, speed=44.4 f/s, elapsed=2:08:22
# Episode 230: reward=-11, steps=3628, speed=44.3 f/s, elapsed=2:09:54
# Episode 231: reward=-10, steps=2733, speed=44.2 f/s, elapsed=2:11:04
# Episode 232: reward=-9, steps=3510, speed=44.1 f/s, elapsed=2:12:33
# Episode 233: reward=-6, steps=3364, speed=44.0 f/s, elapsed=2:13:59
# Episode 234: reward=-9, steps=2899, speed=43.9 f/s, elapsed=2:15:13
# Episode 235: reward=-2, steps=4181, speed=43.8 f/s, elapsed=2:17:01
# Episode 236: reward=-5, steps=3277, speed=43.7 f/s, elapsed=2:18:24
# Episode 237: reward=-10, steps=3176, speed=43.6 f/s, elapsed=2:19:46
# Episode 238: reward=-13, steps=2521, speed=43.5 f/s, elapsed=2:20:50
# Episode 239: reward=-6, steps=3068, speed=43.4 f/s, elapsed=2:22:09
# Episode 240: reward=1, steps=3857, speed=43.3 f/s, elapsed=2:23:47
# Episode 241: reward=-7, steps=3317, speed=43.3 f/s, elapsed=2:25:12
# Episode 242: reward=-5, steps=3347, speed=43.2 f/s, elapsed=2:26:37
# Episode 243: reward=-4, steps=3949, speed=43.1 f/s, elapsed=2:28:18
# Episode 244: reward=-7, steps=3812, speed=43.0 f/s, elapsed=2:29:56
# Episode 245: reward=-3, steps=3963, speed=42.9 f/s, elapsed=2:31:37
# Episode 246: reward=-8, steps=2997, speed=42.9 f/s, elapsed=2:32:53
# Episode 247: reward=-2, steps=3624, speed=42.8 f/s, elapsed=2:34:25
# Episode 248: reward=-9, steps=3296, speed=42.7 f/s, elapsed=2:35:50
# Episode 249: reward=-6, steps=3648, speed=42.7 f/s, elapsed=2:37:22
# Episode 250: reward=-4, steps=3837, speed=42.6 f/s, elapsed=2:39:00
# Episode 251: reward=-8, steps=3455, speed=42.5 f/s, elapsed=2:40:29
# Episode 252: reward=-12, steps=3574, speed=42.5 f/s, elapsed=2:41:59
# Episode 253: reward=-12, steps=2774, speed=42.4 f/s, elapsed=2:43:09
# Episode 254: reward=-7, steps=3523, speed=42.3 f/s, elapsed=2:44:38
# Episode 255: reward=2, steps=3812, speed=42.3 f/s, elapsed=2:46:14
# Episode 256: reward=10, steps=2844, speed=42.2 f/s, elapsed=2:47:34
# Episode 257: reward=-12, steps=2608, speed=42.0 f/s, elapsed=2:48:49
# Episode 258: reward=-2, steps=3311, speed=41.9 f/s, elapsed=2:50:24
# Episode 259: reward=4, steps=4211, speed=41.7 f/s, elapsed=2:52:24
# Episode 260: reward=-10, steps=3574, speed=41.6 f/s, elapsed=2:54:06
# Episode 261: reward=3, steps=3547, speed=41.5 f/s, elapsed=2:55:40
# Episode 262: reward=-5, steps=3138, speed=41.4 f/s, elapsed=2:57:06
# Episode 263: reward=-1, steps=4102, speed=41.3 f/s, elapsed=2:58:59
# Episode 264: reward=-7, steps=3265, speed=41.2 f/s, elapsed=3:00:30
# Episode 265: reward=2, steps=3872, speed=41.1 f/s, elapsed=3:02:17
# Episode 266: reward=-5, steps=3860, speed=41.0 f/s, elapsed=3:04:02
# Episode 267: reward=-11, steps=2910, speed=40.9 f/s, elapsed=3:05:23
# Episode 268: reward=-1, steps=4136, speed=40.8 f/s, elapsed=3:07:14
# Episode 269: reward=2, steps=3736, speed=40.8 f/s, elapsed=3:08:52
# Episode 270: reward=2, steps=4639, speed=40.7 f/s, elapsed=3:10:54
# Episode 271: reward=-6, steps=3532, speed=40.7 f/s, elapsed=3:12:27
# Episode 272: reward=-15, steps=3060, speed=40.6 f/s, elapsed=3:13:48
# Episode 273: reward=-4, steps=3520, speed=40.6 f/s, elapsed=3:15:21
# Episode 274: reward=-7, steps=2914, speed=40.5 f/s, elapsed=3:16:38
# Episode 275: reward=-8, steps=3564, speed=40.5 f/s, elapsed=3:18:11
# Episode 276: reward=-7, steps=3425, speed=40.4 f/s, elapsed=3:19:42
# Episode 277: reward=-2, steps=3604, speed=40.4 f/s, elapsed=3:21:17
# Episode 278: reward=3, steps=3881, speed=40.3 f/s, elapsed=3:22:59
# Episode 279: reward=-4, steps=3464, speed=40.3 f/s, elapsed=3:24:28
# Episode 280: reward=6, steps=3777, speed=40.3 f/s, elapsed=3:26:04
# Episode 281: reward=-3, steps=3805, speed=40.3 f/s, elapsed=3:27:40
# Episode 282: reward=-7, steps=3797, speed=40.2 f/s, elapsed=3:29:18
# Episode 283: reward=5, steps=4538, speed=40.2 f/s, elapsed=3:31:13
# Episode 284: reward=-8, steps=3681, speed=40.2 f/s, elapsed=3:32:49
# Episode 285: reward=8, steps=3594, speed=40.1 f/s, elapsed=3:34:23
# Episode 286: reward=5, steps=3815, speed=40.1 f/s, elapsed=3:36:05
# Episode 287: reward=-3, steps=4094, speed=40.0 f/s, elapsed=3:37:53
# Episode 288: reward=2, steps=3771, speed=40.0 f/s, elapsed=3:39:33
# Episode 289: reward=13, steps=3597, speed=40.0 f/s, elapsed=3:41:07
# Episode 290: reward=7, steps=3548, speed=39.9 f/s, elapsed=3:42:39
# Episode 291: reward=5, steps=4607, speed=39.9 f/s, elapsed=3:44:38
# Episode 292: reward=12, steps=2862, speed=39.9 f/s, elapsed=3:45:53
# Episode 293: reward=14, steps=2814, speed=39.8 f/s, elapsed=3:47:06
# Episode 294: reward=1, steps=3951, speed=39.8 f/s, elapsed=3:48:49
# Episode 295: reward=3, steps=3831, speed=39.8 f/s, elapsed=3:50:30
# Episode 296: reward=10, steps=3323, speed=39.7 f/s, elapsed=3:51:59
# Episode 297: reward=3, steps=4201, speed=39.7 f/s, elapsed=3:53:51
# Episode 298: reward=7, steps=3957, speed=39.6 f/s, elapsed=3:55:37
# Episode 299: reward=3, steps=4294, speed=39.6 f/s, elapsed=3:57:30
# Episode 300: reward=7, steps=3151, speed=39.6 f/s, elapsed=3:58:50
# Episode 301: reward=9, steps=3323, speed=39.6 f/s, elapsed=4:00:16
# Episode 302: reward=8, steps=3241, speed=39.6 f/s, elapsed=4:01:38
# Episode 303: reward=-2, steps=4700, speed=39.6 f/s, elapsed=4:03:40
# Episode 304: reward=2, steps=4209, speed=39.5 f/s, elapsed=4:05:32
# Episode 305: reward=1, steps=4088, speed=39.5 f/s, elapsed=4:07:18
# Episode 306: reward=2, steps=4630, speed=39.5 f/s, elapsed=4:09:20
# Episode 307: reward=10, steps=3289, speed=39.4 f/s, elapsed=4:10:46
# Episode 308: reward=-2, steps=4049, speed=39.4 f/s, elapsed=4:12:31
# Episode 309: reward=12, steps=3104, speed=39.4 f/s, elapsed=4:13:52
# Episode 310: reward=1, steps=3873, speed=39.4 f/s, elapsed=4:15:33
# Episode 311: reward=4, steps=4096, speed=39.4 f/s, elapsed=4:17:16
# Episode 312: reward=13, steps=2883, speed=39.4 f/s, elapsed=4:18:28
# Episode 313: reward=10, steps=3267, speed=39.4 f/s, elapsed=4:19:50
# Episode 314: reward=1, steps=3970, speed=39.4 f/s, elapsed=4:21:29
# Episode 315: reward=9, steps=3133, speed=39.4 f/s, elapsed=4:22:47
# Episode 316: reward=7, steps=3005, speed=39.5 f/s, elapsed=4:24:01
