# %%
import random
import gym
import gym.spaces
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim

# %%
HIDDEN_SIZE = 128
# Batch size is changed from 16 to 100
BATCH_SIZE = 100
# Percentile is changed from 70 to 30
PERCENTILE = 30
# Gamma variable is introduced
GAMMA = 0.9

# %%
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res

# %%
class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

# %%
Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])


def iterate_batches(env, net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.FloatTensor([obs])
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, _ = env.step(action)
        episode_reward += reward
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        if is_done:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward = 0.0
            episode_steps = []
            next_obs = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs

# %%
def filter_batch(batch, percentile):
    # Here each reward is multiplied to gamma to the power of the current step.
    filter_fun = lambda s: s.reward * (GAMMA ** len(s.steps))
    disc_rewards = list(map(filter_fun, batch))
    reward_bound = np.percentile(disc_rewards, percentile)

    train_obs = []
    train_act = []
    elite_batch = []
    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation,
                                 example.steps))
            train_act.extend(map(lambda step: step.action,
                                 example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound

# %%
env = DiscreteOneHotWrapper(gym.make("FrozenLake-v0"))
# env = gym.wrappers.Monitor(env, directory="FrozenLake_tweaked", force=True)
obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

net = Net(obs_size, HIDDEN_SIZE, n_actions)
objective = nn.CrossEntropyLoss()
optimizer = optim.Adam(params=net.parameters(), lr=0.001) # lr is also divided by 10
writer = SummaryWriter(comment="-frozenlake-tweaked")

# %%
full_batch = []
for iter_no, batch in enumerate(iterate_batches(
        env, net, BATCH_SIZE)):
    reward_mean = float(np.mean(list(map(
        lambda s: s.reward, batch))))
    full_batch, obs, acts, reward_bound = \
        filter_batch(full_batch + batch, PERCENTILE)
    if not full_batch:
        continue
    obs_v = torch.FloatTensor(obs)
    acts_v = torch.LongTensor(acts)
    full_batch = full_batch[-500:]

    optimizer.zero_grad()
    action_scores_v = net(obs_v)
    loss_v = objective(action_scores_v, acts_v)
    loss_v.backward()
    optimizer.step()
    print("%d: loss=%.3f, rw_mean=%.3f, "
          "rw_bound=%.3f, batch=%d" % (
        iter_no, loss_v.item(), reward_mean,
        reward_bound, len(full_batch)))
    writer.add_scalar("loss", loss_v.item(), iter_no)
    writer.add_scalar("reward_mean", reward_mean, iter_no)
    writer.add_scalar("reward_bound", reward_bound, iter_no)
    if reward_mean > 0.8:
        print("Solved!")
        break
writer.close()
# Out:
# 0: loss=1.384, rw_mean=0.010, rw_bound=0.000, batch=1
# 1: loss=1.376, rw_mean=0.020, rw_bound=0.000, batch=3
# 2: loss=1.371, rw_mean=0.030, rw_bound=0.000, batch=6
# 3: loss=1.370, rw_mean=0.020, rw_bound=0.000, batch=8
# 4: loss=1.364, rw_mean=0.010, rw_bound=0.000, batch=9
# 5: loss=1.363, rw_mean=0.010, rw_bound=0.000, batch=10
# 6: loss=1.368, rw_mean=0.030, rw_bound=0.000, batch=13
# 7: loss=1.366, rw_mean=0.000, rw_bound=0.000, batch=13
# 8: loss=1.365, rw_mean=0.010, rw_bound=0.000, batch=14
# 9: loss=1.365, rw_mean=0.030, rw_bound=0.000, batch=17
# 10: loss=1.369, rw_mean=0.020, rw_bound=0.000, batch=19
# 11: loss=1.368, rw_mean=0.010, rw_bound=0.000, batch=20
# 12: loss=1.369, rw_mean=0.010, rw_bound=0.000, batch=21
# 13: loss=1.371, rw_mean=0.050, rw_bound=0.000, batch=26
# 14: loss=1.369, rw_mean=0.040, rw_bound=0.000, batch=30
# 15: loss=1.369, rw_mean=0.040, rw_bound=0.000, batch=34
# 16: loss=1.366, rw_mean=0.020, rw_bound=0.000, batch=36
# 17: loss=1.364, rw_mean=0.030, rw_bound=0.000, batch=39
# 18: loss=1.362, rw_mean=0.020, rw_bound=0.000, batch=41
# 19: loss=1.361, rw_mean=0.000, rw_bound=0.000, batch=41
# 20: loss=1.360, rw_mean=0.030, rw_bound=0.000, batch=44
# 21: loss=1.362, rw_mean=0.030, rw_bound=0.000, batch=47
# 22: loss=1.361, rw_mean=0.010, rw_bound=0.000, batch=48
# 23: loss=1.359, rw_mean=0.020, rw_bound=0.000, batch=50
# 24: loss=1.356, rw_mean=0.060, rw_bound=0.000, batch=56
# 25: loss=1.355, rw_mean=0.020, rw_bound=0.000, batch=58
# 26: loss=1.355, rw_mean=0.030, rw_bound=0.000, batch=61
# 27: loss=1.354, rw_mean=0.010, rw_bound=0.000, batch=62
# 28: loss=1.355, rw_mean=0.040, rw_bound=0.000, batch=66
# 29: loss=1.353, rw_mean=0.020, rw_bound=0.000, batch=68
# 30: loss=1.352, rw_mean=0.040, rw_bound=0.000, batch=72
# 31: loss=1.351, rw_mean=0.040, rw_bound=0.000, batch=76
# 32: loss=1.350, rw_mean=0.010, rw_bound=0.000, batch=77
# 33: loss=1.350, rw_mean=0.030, rw_bound=0.000, batch=80
# 34: loss=1.349, rw_mean=0.020, rw_bound=0.000, batch=82
# 35: loss=1.350, rw_mean=0.030, rw_bound=0.000, batch=85
# 36: loss=1.349, rw_mean=0.020, rw_bound=0.000, batch=87
# 37: loss=1.349, rw_mean=0.040, rw_bound=0.000, batch=91
# 38: loss=1.349, rw_mean=0.010, rw_bound=0.000, batch=92
# 39: loss=1.348, rw_mean=0.010, rw_bound=0.000, batch=93
# 40: loss=1.347, rw_mean=0.020, rw_bound=0.000, batch=95
# 41: loss=1.344, rw_mean=0.020, rw_bound=0.000, batch=97
# 42: loss=1.344, rw_mean=0.000, rw_bound=0.000, batch=97
# 43: loss=1.344, rw_mean=0.030, rw_bound=0.000, batch=100
# 44: loss=1.343, rw_mean=0.020, rw_bound=0.000, batch=102
# 45: loss=1.343, rw_mean=0.020, rw_bound=0.000, batch=104
# 46: loss=1.343, rw_mean=0.020, rw_bound=0.000, batch=106
# 47: loss=1.342, rw_mean=0.010, rw_bound=0.000, batch=107
# 48: loss=1.342, rw_mean=0.040, rw_bound=0.000, batch=111
# 49: loss=1.342, rw_mean=0.010, rw_bound=0.000, batch=112
# 50: loss=1.341, rw_mean=0.010, rw_bound=0.000, batch=113
# 51: loss=1.341, rw_mean=0.030, rw_bound=0.000, batch=116
# 52: loss=1.338, rw_mean=0.030, rw_bound=0.000, batch=119
# 53: loss=1.337, rw_mean=0.050, rw_bound=0.000, batch=124
# 54: loss=1.337, rw_mean=0.030, rw_bound=0.000, batch=127
# 55: loss=1.337, rw_mean=0.000, rw_bound=0.000, batch=127
# 56: loss=1.337, rw_mean=0.010, rw_bound=0.000, batch=128
# 57: loss=1.337, rw_mean=0.050, rw_bound=0.000, batch=133
# 58: loss=1.336, rw_mean=0.030, rw_bound=0.000, batch=136
# 59: loss=1.335, rw_mean=0.010, rw_bound=0.000, batch=137
# 60: loss=1.335, rw_mean=0.000, rw_bound=0.000, batch=137
# 61: loss=1.332, rw_mean=0.040, rw_bound=0.000, batch=141
# 62: loss=1.331, rw_mean=0.020, rw_bound=0.000, batch=143
# 63: loss=1.331, rw_mean=0.010, rw_bound=0.000, batch=144
# 64: loss=1.331, rw_mean=0.000, rw_bound=0.000, batch=144
# 65: loss=1.330, rw_mean=0.000, rw_bound=0.000, batch=144
# 66: loss=1.329, rw_mean=0.010, rw_bound=0.000, batch=145
# 67: loss=1.329, rw_mean=0.000, rw_bound=0.000, batch=145
# 68: loss=1.329, rw_mean=0.020, rw_bound=0.000, batch=147
# 69: loss=1.329, rw_mean=0.040, rw_bound=0.000, batch=151
# 70: loss=1.328, rw_mean=0.040, rw_bound=0.000, batch=155
# 71: loss=1.327, rw_mean=0.010, rw_bound=0.000, batch=156
# 72: loss=1.326, rw_mean=0.020, rw_bound=0.000, batch=158
# 73: loss=1.326, rw_mean=0.000, rw_bound=0.000, batch=158
# 74: loss=1.325, rw_mean=0.040, rw_bound=0.000, batch=162
# 75: loss=1.325, rw_mean=0.050, rw_bound=0.000, batch=167
# 76: loss=1.323, rw_mean=0.040, rw_bound=0.000, batch=171
# 77: loss=1.323, rw_mean=0.000, rw_bound=0.000, batch=171
# 78: loss=1.322, rw_mean=0.000, rw_bound=0.000, batch=171
# 79: loss=1.321, rw_mean=0.030, rw_bound=0.000, batch=174
# 80: loss=1.320, rw_mean=0.040, rw_bound=0.000, batch=178
# 81: loss=1.319, rw_mean=0.030, rw_bound=0.000, batch=181
# 82: loss=1.318, rw_mean=0.030, rw_bound=0.000, batch=184
# 83: loss=1.318, rw_mean=0.020, rw_bound=0.000, batch=186
# 84: loss=1.317, rw_mean=0.030, rw_bound=0.000, batch=189
# 85: loss=1.316, rw_mean=0.030, rw_bound=0.000, batch=192
# 86: loss=1.315, rw_mean=0.010, rw_bound=0.000, batch=193
# 87: loss=1.314, rw_mean=0.020, rw_bound=0.000, batch=195
# 88: loss=1.313, rw_mean=0.030, rw_bound=0.000, batch=198
# 89: loss=1.312, rw_mean=0.040, rw_bound=0.000, batch=202
# 90: loss=1.311, rw_mean=0.020, rw_bound=0.000, batch=204
# 91: loss=1.310, rw_mean=0.020, rw_bound=0.000, batch=206
# 92: loss=1.310, rw_mean=0.030, rw_bound=0.000, batch=209
# 93: loss=1.308, rw_mean=0.020, rw_bound=0.000, batch=211
# 94: loss=1.308, rw_mean=0.040, rw_bound=0.000, batch=215
# 95: loss=1.308, rw_mean=0.010, rw_bound=0.000, batch=216
# 96: loss=1.308, rw_mean=0.020, rw_bound=0.000, batch=218
# 97: loss=1.306, rw_mean=0.030, rw_bound=0.000, batch=221
# 98: loss=1.306, rw_mean=0.030, rw_bound=0.000, batch=224
# 99: loss=1.304, rw_mean=0.040, rw_bound=0.039, batch=227
# 100: loss=1.303, rw_mean=0.030, rw_bound=0.046, batch=229
# 101: loss=1.301, rw_mean=0.020, rw_bound=0.049, batch=230
# 102: loss=1.301, rw_mean=0.000, rw_bound=0.000, batch=230
# 103: loss=1.298, rw_mean=0.030, rw_bound=0.056, batch=231
# 104: loss=1.296, rw_mean=0.020, rw_bound=0.065, batch=230
# 105: loss=1.295, rw_mean=0.030, rw_bound=0.077, batch=231
# 106: loss=1.294, rw_mean=0.010, rw_bound=0.080, batch=229
# 107: loss=1.294, rw_mean=0.000, rw_bound=0.000, batch=229
# 108: loss=1.294, rw_mean=0.050, rw_bound=0.089, batch=227
# 109: loss=1.292, rw_mean=0.040, rw_bound=0.098, batch=226
# 110: loss=1.292, rw_mean=0.020, rw_bound=0.055, batch=228
# 111: loss=1.292, rw_mean=0.010, rw_bound=0.011, batch=229
# 112: loss=1.289, rw_mean=0.040, rw_bound=0.109, batch=225
# 113: loss=1.289, rw_mean=0.010, rw_bound=0.000, batch=226
# 114: loss=1.283, rw_mean=0.030, rw_bound=0.122, batch=218
# 115: loss=1.282, rw_mean=0.020, rw_bound=0.000, batch=220
# 116: loss=1.281, rw_mean=0.020, rw_bound=0.000, batch=222
# 117: loss=1.280, rw_mean=0.010, rw_bound=0.000, batch=223
# 118: loss=1.280, rw_mean=0.030, rw_bound=0.081, batch=226
# 119: loss=1.279, rw_mean=0.030, rw_bound=0.122, batch=228
# 120: loss=1.278, rw_mean=0.010, rw_bound=0.014, batch=229
# 121: loss=1.274, rw_mean=0.060, rw_bound=0.135, batch=221
# 122: loss=1.270, rw_mean=0.040, rw_bound=0.150, batch=217
# 123: loss=1.270, rw_mean=0.040, rw_bound=0.000, batch=221
# 124: loss=1.269, rw_mean=0.030, rw_bound=0.000, batch=224
# 125: loss=1.268, rw_mean=0.030, rw_bound=0.150, batch=227
# 126: loss=1.266, rw_mean=0.050, rw_bound=0.167, batch=221
# 127: loss=1.264, rw_mean=0.040, rw_bound=0.122, batch=224
# 128: loss=1.264, rw_mean=0.010, rw_bound=0.000, batch=225
# 129: loss=1.262, rw_mean=0.020, rw_bound=0.037, batch=227
# 130: loss=1.256, rw_mean=0.030, rw_bound=0.185, batch=216
# 131: loss=1.256, rw_mean=0.020, rw_bound=0.000, batch=218
# 132: loss=1.255, rw_mean=0.060, rw_bound=0.206, batch=204
# 133: loss=1.256, rw_mean=0.020, rw_bound=0.000, batch=206
# 134: loss=1.257, rw_mean=0.040, rw_bound=0.000, batch=210
# 135: loss=1.257, rw_mean=0.040, rw_bound=0.000, batch=214
# 136: loss=1.255, rw_mean=0.020, rw_bound=0.000, batch=216
# 137: loss=1.254, rw_mean=0.060, rw_bound=0.060, batch=221
# 138: loss=1.255, rw_mean=0.070, rw_bound=0.150, batch=221
# 139: loss=1.255, rw_mean=0.030, rw_bound=0.000, batch=224
# 140: loss=1.255, rw_mean=0.060, rw_bound=0.162, batch=227
# 141: loss=1.253, rw_mean=0.030, rw_bound=0.167, batch=226
# 142: loss=1.253, rw_mean=0.020, rw_bound=0.068, batch=228
# 143: loss=1.250, rw_mean=0.040, rw_bound=0.185, batch=228
# 144: loss=1.243, rw_mean=0.020, rw_bound=0.229, batch=214
# 145: loss=1.243, rw_mean=0.030, rw_bound=0.000, batch=217
# 146: loss=1.241, rw_mean=0.030, rw_bound=0.000, batch=220
# 147: loss=1.241, rw_mean=0.020, rw_bound=0.000, batch=222
# 148: loss=1.239, rw_mean=0.050, rw_bound=0.107, batch=225
# 149: loss=1.239, rw_mean=0.040, rw_bound=0.150, batch=226
# 150: loss=1.238, rw_mean=0.050, rw_bound=0.185, batch=227
# 151: loss=1.237, rw_mean=0.050, rw_bound=0.229, batch=228
# 152: loss=1.236, rw_mean=0.010, rw_bound=0.017, batch=229
# 153: loss=1.227, rw_mean=0.050, rw_bound=0.254, batch=211
# 154: loss=1.225, rw_mean=0.050, rw_bound=0.000, batch=216
# 155: loss=1.223, rw_mean=0.050, rw_bound=0.029, batch=221
# 156: loss=1.222, rw_mean=0.030, rw_bound=0.000, batch=224
# 157: loss=1.220, rw_mean=0.040, rw_bound=0.070, batch=227
# 158: loss=1.220, rw_mean=0.090, rw_bound=0.206, batch=228
# 159: loss=1.219, rw_mean=0.050, rw_bound=0.282, batch=199
# 160: loss=1.217, rw_mean=0.050, rw_bound=0.000, batch=204
# 161: loss=1.214, rw_mean=0.050, rw_bound=0.000, batch=209
# 162: loss=1.215, rw_mean=0.020, rw_bound=0.000, batch=211
# 163: loss=1.214, rw_mean=0.030, rw_bound=0.000, batch=214
# 164: loss=1.214, rw_mean=0.070, rw_bound=0.059, batch=220
# 165: loss=1.212, rw_mean=0.040, rw_bound=0.045, batch=224
# 166: loss=1.214, rw_mean=0.050, rw_bound=0.122, batch=226
# 167: loss=1.213, rw_mean=0.060, rw_bound=0.196, batch=228
# 168: loss=1.211, rw_mean=0.040, rw_bound=0.208, batch=229
# 169: loss=1.210, rw_mean=0.030, rw_bound=0.254, batch=227
# 170: loss=1.211, rw_mean=0.050, rw_bound=0.263, batch=229
# 171: loss=1.214, rw_mean=0.040, rw_bound=0.282, batch=227
# 172: loss=1.213, rw_mean=0.020, rw_bound=0.251, batch=229
# 173: loss=1.206, rw_mean=0.050, rw_bound=0.314, batch=192
# 174: loss=1.206, rw_mean=0.050, rw_bound=0.000, batch=197
# 175: loss=1.205, rw_mean=0.080, rw_bound=0.000, batch=205
# 176: loss=1.205, rw_mean=0.020, rw_bound=0.000, batch=207
# 177: loss=1.205, rw_mean=0.080, rw_bound=0.012, batch=215
# 178: loss=1.202, rw_mean=0.020, rw_bound=0.000, batch=217
# 179: loss=1.200, rw_mean=0.060, rw_bound=0.049, batch=222
# 180: loss=1.203, rw_mean=0.060, rw_bound=0.135, batch=225
# 181: loss=1.198, rw_mean=0.050, rw_bound=0.167, batch=226
# 182: loss=1.197, rw_mean=0.070, rw_bound=0.229, batch=227
# 183: loss=1.196, rw_mean=0.040, rw_bound=0.254, batch=224
# 184: loss=1.194, rw_mean=0.050, rw_bound=0.224, batch=227
# 185: loss=1.194, rw_mean=0.040, rw_bound=0.282, batch=226
# 186: loss=1.195, rw_mean=0.060, rw_bound=0.314, batch=223
# 187: loss=1.194, rw_mean=0.020, rw_bound=0.000, batch=225
# 188: loss=1.195, rw_mean=0.040, rw_bound=0.234, batch=227
# 189: loss=1.195, rw_mean=0.010, rw_bound=0.000, batch=228
# 190: loss=1.193, rw_mean=0.070, rw_bound=0.282, batch=228
# 191: loss=1.171, rw_mean=0.040, rw_bound=0.349, batch=182
# 192: loss=1.172, rw_mean=0.020, rw_bound=0.000, batch=184
# 193: loss=1.173, rw_mean=0.030, rw_bound=0.000, batch=187
# 194: loss=1.170, rw_mean=0.080, rw_bound=0.000, batch=195
# 195: loss=1.172, rw_mean=0.040, rw_bound=0.000, batch=199
# 196: loss=1.175, rw_mean=0.060, rw_bound=0.000, batch=205
# 197: loss=1.173, rw_mean=0.030, rw_bound=0.000, batch=208
# 198: loss=1.169, rw_mean=0.110, rw_bound=0.185, batch=214
# 199: loss=1.165, rw_mean=0.100, rw_bound=0.204, batch=220
# 200: loss=1.164, rw_mean=0.040, rw_bound=0.105, batch=224
# 201: loss=1.163, rw_mean=0.040, rw_bound=0.182, batch=227
# 202: loss=1.164, rw_mean=0.060, rw_bound=0.229, batch=227
# 203: loss=1.163, rw_mean=0.050, rw_bound=0.249, batch=229
# 204: loss=1.163, rw_mean=0.030, rw_bound=0.265, batch=230
# 205: loss=1.162, rw_mean=0.050, rw_bound=0.282, batch=228
# 206: loss=1.164, rw_mean=0.070, rw_bound=0.314, batch=223
# 207: loss=1.163, rw_mean=0.050, rw_bound=0.244, batch=226
# 208: loss=1.164, rw_mean=0.060, rw_bound=0.298, batch=228
# 209: loss=1.165, rw_mean=0.060, rw_bound=0.317, batch=229
# 210: loss=1.163, rw_mean=0.040, rw_bound=0.349, batch=217
# 211: loss=1.162, rw_mean=0.050, rw_bound=0.015, batch=222
# 212: loss=1.163, rw_mean=0.110, rw_bound=0.245, batch=225
# 213: loss=1.163, rw_mean=0.040, rw_bound=0.282, batch=226
# 214: loss=1.163, rw_mean=0.060, rw_bound=0.282, batch=227
# 215: loss=1.163, rw_mean=0.030, rw_bound=0.122, batch=228
# 216: loss=1.159, rw_mean=0.070, rw_bound=0.353, batch=229
# 217: loss=1.159, rw_mean=0.010, rw_bound=0.139, batch=230
# 218: loss=1.158, rw_mean=0.060, rw_bound=0.288, batch=231
# 219: loss=1.146, rw_mean=0.050, rw_bound=0.387, batch=172
# 220: loss=1.143, rw_mean=0.070, rw_bound=0.000, batch=179
# 221: loss=1.148, rw_mean=0.070, rw_bound=0.000, batch=186
# 222: loss=1.146, rw_mean=0.030, rw_bound=0.000, batch=189
# 223: loss=1.150, rw_mean=0.060, rw_bound=0.000, batch=195
# 224: loss=1.147, rw_mean=0.060, rw_bound=0.000, batch=201
# 225: loss=1.147, rw_mean=0.050, rw_bound=0.000, batch=206
# 226: loss=1.147, rw_mean=0.020, rw_bound=0.000, batch=208
# 227: loss=1.145, rw_mean=0.010, rw_bound=0.000, batch=209
# 228: loss=1.143, rw_mean=0.030, rw_bound=0.000, batch=212
# 229: loss=1.143, rw_mean=0.030, rw_bound=0.000, batch=215
# 230: loss=1.140, rw_mean=0.070, rw_bound=0.098, batch=219
# 231: loss=1.138, rw_mean=0.030, rw_bound=0.000, batch=222
# 232: loss=1.138, rw_mean=0.040, rw_bound=0.057, batch=225
# 233: loss=1.136, rw_mean=0.030, rw_bound=0.115, batch=227
# 234: loss=1.139, rw_mean=0.060, rw_bound=0.167, batch=227
# 235: loss=1.140, rw_mean=0.060, rw_bound=0.185, batch=228
# 236: loss=1.138, rw_mean=0.060, rw_bound=0.208, batch=229
# 237: loss=1.138, rw_mean=0.080, rw_bound=0.282, batch=223
# 238: loss=1.137, rw_mean=0.010, rw_bound=0.000, batch=224
# 239: loss=1.136, rw_mean=0.040, rw_bound=0.233, batch=227
# 240: loss=1.137, rw_mean=0.080, rw_bound=0.314, batch=223
# 241: loss=1.136, rw_mean=0.060, rw_bound=0.198, batch=226
# 242: loss=1.133, rw_mean=0.080, rw_bound=0.316, batch=228
# 243: loss=1.133, rw_mean=0.030, rw_bound=0.317, batch=229
# 244: loss=1.129, rw_mean=0.060, rw_bound=0.349, batch=225
# 245: loss=1.128, rw_mean=0.040, rw_bound=0.199, batch=227
# 246: loss=1.128, rw_mean=0.070, rw_bound=0.249, batch=229
# 247: loss=1.127, rw_mean=0.050, rw_bound=0.254, batch=229
# 248: loss=1.131, rw_mean=0.040, rw_bound=0.387, batch=213
# 249: loss=1.128, rw_mean=0.050, rw_bound=0.000, batch=218
# 250: loss=1.129, rw_mean=0.050, rw_bound=0.080, batch=222
# 251: loss=1.127, rw_mean=0.060, rw_bound=0.150, batch=224
# 252: loss=1.126, rw_mean=0.070, rw_bound=0.254, batch=226
# 253: loss=1.125, rw_mean=0.040, rw_bound=0.244, batch=228
# 254: loss=1.126, rw_mean=0.050, rw_bound=0.282, batch=227
# 255: loss=1.124, rw_mean=0.100, rw_bound=0.342, batch=229
# 256: loss=1.123, rw_mean=0.030, rw_bound=0.292, batch=230
# 257: loss=1.126, rw_mean=0.040, rw_bound=0.349, batch=226
# 258: loss=1.128, rw_mean=0.080, rw_bound=0.387, batch=225
# 259: loss=1.133, rw_mean=0.050, rw_bound=0.430, batch=142
# 260: loss=1.132, rw_mean=0.070, rw_bound=0.000, batch=149
# 261: loss=1.135, rw_mean=0.050, rw_bound=0.000, batch=154
# 262: loss=1.136, rw_mean=0.030, rw_bound=0.000, batch=157
# 263: loss=1.134, rw_mean=0.070, rw_bound=0.000, batch=164
# 264: loss=1.138, rw_mean=0.050, rw_bound=0.000, batch=169
# 265: loss=1.137, rw_mean=0.050, rw_bound=0.000, batch=174
# 266: loss=1.130, rw_mean=0.070, rw_bound=0.000, batch=181
# 267: loss=1.132, rw_mean=0.060, rw_bound=0.000, batch=187
# 268: loss=1.130, rw_mean=0.090, rw_bound=0.000, batch=196
# 269: loss=1.130, rw_mean=0.040, rw_bound=0.000, batch=200
# 270: loss=1.128, rw_mean=0.020, rw_bound=0.000, batch=202
# 271: loss=1.124, rw_mean=0.090, rw_bound=0.007, batch=211
# 272: loss=1.122, rw_mean=0.040, rw_bound=0.000, batch=215
# 273: loss=1.119, rw_mean=0.030, rw_bound=0.000, batch=218
# 274: loss=1.113, rw_mean=0.130, rw_bound=0.100, batch=222
# 275: loss=1.114, rw_mean=0.080, rw_bound=0.122, batch=224
# 276: loss=1.112, rw_mean=0.020, rw_bound=0.000, batch=226
# 277: loss=1.116, rw_mean=0.050, rw_bound=0.135, batch=226
# 278: loss=1.119, rw_mean=0.100, rw_bound=0.185, batch=221
# 279: loss=1.121, rw_mean=0.090, rw_bound=0.206, batch=223
# 280: loss=1.120, rw_mean=0.080, rw_bound=0.229, batch=225
# 281: loss=1.121, rw_mean=0.030, rw_bound=0.254, batch=220
# 282: loss=1.120, rw_mean=0.030, rw_bound=0.000, batch=223
# 283: loss=1.120, rw_mean=0.040, rw_bound=0.110, batch=226
# 284: loss=1.124, rw_mean=0.090, rw_bound=0.282, batch=213
# 285: loss=1.122, rw_mean=0.080, rw_bound=0.172, batch=219
# 286: loss=1.126, rw_mean=0.030, rw_bound=0.000, batch=222
# 287: loss=1.121, rw_mean=0.050, rw_bound=0.191, batch=225
# 288: loss=1.120, rw_mean=0.050, rw_bound=0.234, batch=227
# 289: loss=1.120, rw_mean=0.040, rw_bound=0.277, batch=229
# 290: loss=1.125, rw_mean=0.090, rw_bound=0.314, batch=209
# 291: loss=1.128, rw_mean=0.120, rw_bound=0.349, batch=200
# 292: loss=1.133, rw_mean=0.050, rw_bound=0.000, batch=205
# 293: loss=1.130, rw_mean=0.060, rw_bound=0.000, batch=211
# 294: loss=1.125, rw_mean=0.070, rw_bound=0.135, batch=216
# 295: loss=1.124, rw_mean=0.090, rw_bound=0.241, batch=221
# 296: loss=1.118, rw_mean=0.070, rw_bound=0.282, batch=220
# 297: loss=1.115, rw_mean=0.080, rw_bound=0.314, batch=219
# 298: loss=1.117, rw_mean=0.060, rw_bound=0.225, batch=223
# 299: loss=1.118, rw_mean=0.030, rw_bound=0.028, batch=226
# 300: loss=1.115, rw_mean=0.050, rw_bound=0.189, batch=228
# 301: loss=1.114, rw_mean=0.050, rw_bound=0.282, batch=228
# 302: loss=1.113, rw_mean=0.070, rw_bound=0.314, batch=226
# 303: loss=1.114, rw_mean=0.080, rw_bound=0.331, batch=228
# 304: loss=1.116, rw_mean=0.050, rw_bound=0.349, batch=225
# 305: loss=1.116, rw_mean=0.040, rw_bound=0.296, batch=227
# 306: loss=1.115, rw_mean=0.020, rw_bound=0.148, batch=229
# 307: loss=1.113, rw_mean=0.040, rw_bound=0.277, batch=230
# 308: loss=1.114, rw_mean=0.060, rw_bound=0.349, batch=230
# 309: loss=1.116, rw_mean=0.030, rw_bound=0.210, batch=231
# 310: loss=1.113, rw_mean=0.030, rw_bound=0.229, batch=231
# 311: loss=1.116, rw_mean=0.060, rw_bound=0.387, batch=211
# 312: loss=1.119, rw_mean=0.030, rw_bound=0.000, batch=214
# 313: loss=1.117, rw_mean=0.060, rw_bound=0.058, batch=220
# 314: loss=1.117, rw_mean=0.000, rw_bound=0.000, batch=220
# 315: loss=1.117, rw_mean=0.020, rw_bound=0.000, batch=222
# 316: loss=1.118, rw_mean=0.050, rw_bound=0.072, batch=225
# 317: loss=1.116, rw_mean=0.020, rw_bound=0.018, batch=227
# 318: loss=1.113, rw_mean=0.070, rw_bound=0.229, batch=227
# 319: loss=1.120, rw_mean=0.120, rw_bound=0.308, batch=229
# 320: loss=1.115, rw_mean=0.090, rw_bound=0.314, batch=229
# 321: loss=1.116, rw_mean=0.040, rw_bound=0.309, batch=230
# 322: loss=1.114, rw_mean=0.040, rw_bound=0.349, batch=227
# 323: loss=1.112, rw_mean=0.040, rw_bound=0.320, batch=229
# 324: loss=1.111, rw_mean=0.050, rw_bound=0.387, batch=223
# 325: loss=1.109, rw_mean=0.060, rw_bound=0.220, batch=226
# 326: loss=1.110, rw_mean=0.060, rw_bound=0.314, batch=225
# 327: loss=1.111, rw_mean=0.050, rw_bound=0.251, batch=227
# 328: loss=1.111, rw_mean=0.070, rw_bound=0.422, batch=229
# 329: loss=1.124, rw_mean=0.070, rw_bound=0.430, batch=197
# 330: loss=1.114, rw_mean=0.080, rw_bound=0.000, batch=205
# 331: loss=1.114, rw_mean=0.030, rw_bound=0.000, batch=208
# 332: loss=1.107, rw_mean=0.080, rw_bound=0.098, batch=214
# 333: loss=1.109, rw_mean=0.110, rw_bound=0.199, batch=220
# 334: loss=1.109, rw_mean=0.050, rw_bound=0.200, batch=224
# 335: loss=1.109, rw_mean=0.060, rw_bound=0.197, batch=227
# 336: loss=1.107, rw_mean=0.040, rw_bound=0.187, batch=229
# 337: loss=1.108, rw_mean=0.050, rw_bound=0.206, batch=229
# 338: loss=1.109, rw_mean=0.060, rw_bound=0.254, batch=229
# 339: loss=1.110, rw_mean=0.040, rw_bound=0.282, batch=226
# 340: loss=1.110, rw_mean=0.070, rw_bound=0.256, batch=228
# 341: loss=1.110, rw_mean=0.040, rw_bound=0.257, batch=229
# 342: loss=1.107, rw_mean=0.050, rw_bound=0.282, batch=229
# 343: loss=1.112, rw_mean=0.060, rw_bound=0.314, batch=221
# 344: loss=1.113, rw_mean=0.090, rw_bound=0.314, batch=224
# 345: loss=1.115, rw_mean=0.100, rw_bound=0.349, batch=225
# 346: loss=1.117, rw_mean=0.070, rw_bound=0.387, batch=218
# 347: loss=1.118, rw_mean=0.080, rw_bound=0.260, batch=222
# 348: loss=1.115, rw_mean=0.060, rw_bound=0.314, batch=224
# 349: loss=1.112, rw_mean=0.070, rw_bound=0.349, batch=225
# 350: loss=1.112, rw_mean=0.050, rw_bound=0.289, batch=227
# 351: loss=1.110, rw_mean=0.050, rw_bound=0.308, batch=229
# 352: loss=1.109, rw_mean=0.080, rw_bound=0.314, batch=229
# 353: loss=1.109, rw_mean=0.040, rw_bound=0.295, batch=230
# 354: loss=1.111, rw_mean=0.150, rw_bound=0.387, batch=228
# 355: loss=1.111, rw_mean=0.020, rw_bound=0.357, batch=229
# 356: loss=1.111, rw_mean=0.040, rw_bound=0.405, batch=230
# 357: loss=1.111, rw_mean=0.050, rw_bound=0.418, batch=231
# 358: loss=1.117, rw_mean=0.070, rw_bound=0.430, batch=217
# 359: loss=1.116, rw_mean=0.060, rw_bound=0.342, batch=222
# 360: loss=1.115, rw_mean=0.030, rw_bound=0.024, batch=225
# 361: loss=1.114, rw_mean=0.050, rw_bound=0.349, batch=223
# 362: loss=1.112, rw_mean=0.070, rw_bound=0.349, batch=225
# 363: loss=1.111, rw_mean=0.060, rw_bound=0.329, batch=227
# 364: loss=1.112, rw_mean=0.070, rw_bound=0.380, batch=229
# 365: loss=1.111, rw_mean=0.040, rw_bound=0.213, batch=230
# 366: loss=1.111, rw_mean=0.080, rw_bound=0.282, batch=230
# 367: loss=1.110, rw_mean=0.030, rw_bound=0.304, batch=231
# 368: loss=1.111, rw_mean=0.020, rw_bound=0.314, batch=231
# 369: loss=1.111, rw_mean=0.040, rw_bound=0.349, batch=231
# 370: loss=1.113, rw_mean=0.040, rw_bound=0.387, batch=226
# 371: loss=1.114, rw_mean=0.070, rw_bound=0.387, batch=227
# 372: loss=1.114, rw_mean=0.060, rw_bound=0.342, batch=229
# 373: loss=1.115, rw_mean=0.050, rw_bound=0.328, batch=230
# 374: loss=1.115, rw_mean=0.030, rw_bound=0.304, batch=231
# 375: loss=1.114, rw_mean=0.030, rw_bound=0.349, batch=229
# 376: loss=1.114, rw_mean=0.070, rw_bound=0.295, batch=230
# 377: loss=1.114, rw_mean=0.060, rw_bound=0.430, batch=224
# 378: loss=1.113, rw_mean=0.050, rw_bound=0.275, batch=227
# 379: loss=1.115, rw_mean=0.050, rw_bound=0.250, batch=229
# 380: loss=1.116, rw_mean=0.050, rw_bound=0.309, batch=230
# 381: loss=1.115, rw_mean=0.030, rw_bound=0.313, batch=231
# 382: loss=1.114, rw_mean=0.060, rw_bound=0.387, batch=229
# 383: loss=1.113, rw_mean=0.060, rw_bound=0.342, batch=230
# 384: loss=1.112, rw_mean=0.040, rw_bound=0.395, batch=231
# 385: loss=1.112, rw_mean=0.030, rw_bound=0.254, batch=231
# 386: loss=1.114, rw_mean=0.080, rw_bound=0.430, batch=230
# 387: loss=1.113, rw_mean=0.050, rw_bound=0.464, batch=231
# 388: loss=1.062, rw_mean=0.140, rw_bound=0.478, batch=104
# 389: loss=1.062, rw_mean=0.020, rw_bound=0.000, batch=106
# 390: loss=1.067, rw_mean=0.060, rw_bound=0.000, batch=112
# 391: loss=1.063, rw_mean=0.050, rw_bound=0.000, batch=117
# 392: loss=1.054, rw_mean=0.070, rw_bound=0.000, batch=124
# 393: loss=1.061, rw_mean=0.070, rw_bound=0.000, batch=131
# 394: loss=1.065, rw_mean=0.050, rw_bound=0.000, batch=136
# 395: loss=1.064, rw_mean=0.070, rw_bound=0.000, batch=143
# 396: loss=1.065, rw_mean=0.070, rw_bound=0.000, batch=150
# 397: loss=1.062, rw_mean=0.070, rw_bound=0.000, batch=157
# 398: loss=1.065, rw_mean=0.040, rw_bound=0.000, batch=161
# 399: loss=1.062, rw_mean=0.030, rw_bound=0.000, batch=164
# 400: loss=1.064, rw_mean=0.050, rw_bound=0.000, batch=169
# 401: loss=1.066, rw_mean=0.110, rw_bound=0.000, batch=180
# 402: loss=1.064, rw_mean=0.020, rw_bound=0.000, batch=182
# 403: loss=1.066, rw_mean=0.100, rw_bound=0.000, batch=192
# 404: loss=1.063, rw_mean=0.050, rw_bound=0.000, batch=197
# 405: loss=1.061, rw_mean=0.070, rw_bound=0.000, batch=204
# 406: loss=1.058, rw_mean=0.090, rw_bound=0.031, batch=213
# 407: loss=1.058, rw_mean=0.030, rw_bound=0.000, batch=216
# 408: loss=1.061, rw_mean=0.060, rw_bound=0.034, batch=220
# 409: loss=1.060, rw_mean=0.040, rw_bound=0.030, batch=224
# 410: loss=1.058, rw_mean=0.050, rw_bound=0.052, batch=227
# 411: loss=1.059, rw_mean=0.080, rw_bound=0.089, batch=231
# 412: loss=1.062, rw_mean=0.090, rw_bound=0.150, batch=229
# 413: loss=1.064, rw_mean=0.030, rw_bound=0.167, batch=224
# 414: loss=1.061, rw_mean=0.080, rw_bound=0.185, batch=219
# 415: loss=1.057, rw_mean=0.050, rw_bound=0.206, batch=213
# 416: loss=1.058, rw_mean=0.050, rw_bound=0.000, batch=218
# 417: loss=1.055, rw_mean=0.050, rw_bound=0.037, batch=222
# 418: loss=1.050, rw_mean=0.070, rw_bound=0.229, batch=209
# 419: loss=1.048, rw_mean=0.070, rw_bound=0.067, batch=216
# 420: loss=1.048, rw_mean=0.040, rw_bound=0.000, batch=220
# 421: loss=1.049, rw_mean=0.080, rw_bound=0.200, batch=224
# 422: loss=1.050, rw_mean=0.080, rw_bound=0.226, batch=227
# 423: loss=1.051, rw_mean=0.020, rw_bound=0.183, batch=229
# 424: loss=1.050, rw_mean=0.070, rw_bound=0.229, batch=229
# 425: loss=1.046, rw_mean=0.060, rw_bound=0.254, batch=218
# 426: loss=1.044, rw_mean=0.110, rw_bound=0.282, batch=211
# 427: loss=1.040, rw_mean=0.090, rw_bound=0.229, batch=217
# 428: loss=1.040, rw_mean=0.010, rw_bound=0.000, batch=218
# 429: loss=1.041, rw_mean=0.070, rw_bound=0.229, batch=221
# 430: loss=1.040, rw_mean=0.100, rw_bound=0.282, batch=222
# 431: loss=1.046, rw_mean=0.070, rw_bound=0.314, batch=214
# 432: loss=1.045, rw_mean=0.060, rw_bound=0.206, batch=220
# 433: loss=1.041, rw_mean=0.100, rw_bound=0.222, batch=224
# 434: loss=1.038, rw_mean=0.070, rw_bound=0.221, batch=227
# 435: loss=1.039, rw_mean=0.070, rw_bound=0.272, batch=229
# 436: loss=1.042, rw_mean=0.030, rw_bound=0.282, batch=226
# 437: loss=1.043, rw_mean=0.040, rw_bound=0.250, batch=228
# 438: loss=1.046, rw_mean=0.070, rw_bound=0.314, batch=227
# 439: loss=1.047, rw_mean=0.010, rw_bound=0.000, batch=228
# 440: loss=1.050, rw_mean=0.060, rw_bound=0.349, batch=199
# 441: loss=1.047, rw_mean=0.040, rw_bound=0.000, batch=203
# 442: loss=1.047, rw_mean=0.050, rw_bound=0.000, batch=208
# 443: loss=1.046, rw_mean=0.020, rw_bound=0.000, batch=210
# 444: loss=1.046, rw_mean=0.070, rw_bound=0.105, batch=217
# 445: loss=1.039, rw_mean=0.070, rw_bound=0.150, batch=221
# 446: loss=1.035, rw_mean=0.080, rw_bound=0.206, batch=223
# 447: loss=1.033, rw_mean=0.060, rw_bound=0.220, batch=226
# 448: loss=1.033, rw_mean=0.030, rw_bound=0.169, batch=228
# 449: loss=1.039, rw_mean=0.070, rw_bound=0.254, batch=225
# 450: loss=1.037, rw_mean=0.080, rw_bound=0.282, batch=226
# 451: loss=1.042, rw_mean=0.090, rw_bound=0.349, batch=222
# 452: loss=1.042, rw_mean=0.020, rw_bound=0.000, batch=224
# 453: loss=1.042, rw_mean=0.060, rw_bound=0.314, batch=226
# 454: loss=1.040, rw_mean=0.110, rw_bound=0.349, batch=227
# 455: loss=1.040, rw_mean=0.020, rw_bound=0.079, batch=229
# 456: loss=1.045, rw_mean=0.130, rw_bound=0.387, batch=196
# 457: loss=1.043, rw_mean=0.120, rw_bound=0.136, batch=207
# 458: loss=1.041, rw_mean=0.070, rw_bound=0.000, batch=214
# 459: loss=1.038, rw_mean=0.090, rw_bound=0.150, batch=219
# 460: loss=1.041, rw_mean=0.060, rw_bound=0.167, batch=222
# 461: loss=1.042, rw_mean=0.080, rw_bound=0.213, batch=225
# 462: loss=1.045, rw_mean=0.070, rw_bound=0.254, batch=223
# 463: loss=1.045, rw_mean=0.010, rw_bound=0.000, batch=224
# 464: loss=1.041, rw_mean=0.060, rw_bound=0.204, batch=227
# 465: loss=1.038, rw_mean=0.090, rw_bound=0.282, batch=223
# 466: loss=1.038, rw_mean=0.050, rw_bound=0.314, batch=223
# 467: loss=1.043, rw_mean=0.100, rw_bound=0.349, batch=222
# 468: loss=1.044, rw_mean=0.080, rw_bound=0.254, batch=224
# 469: loss=1.043, rw_mean=0.080, rw_bound=0.247, batch=227
# 470: loss=1.044, rw_mean=0.090, rw_bound=0.366, batch=229
# 471: loss=1.044, rw_mean=0.060, rw_bound=0.349, batch=229
# 472: loss=1.049, rw_mean=0.070, rw_bound=0.387, batch=216
# 473: loss=1.051, rw_mean=0.090, rw_bound=0.206, batch=220
# 474: loss=1.048, rw_mean=0.120, rw_bound=0.338, batch=224
# 475: loss=1.045, rw_mean=0.060, rw_bound=0.249, batch=227
# 476: loss=1.044, rw_mean=0.090, rw_bound=0.380, batch=229
# 477: loss=1.048, rw_mean=0.110, rw_bound=0.387, batch=224
# 478: loss=1.046, rw_mean=0.070, rw_bound=0.345, batch=227
# 479: loss=1.047, rw_mean=0.060, rw_bound=0.335, batch=229
# 480: loss=1.045, rw_mean=0.080, rw_bound=0.405, batch=230
# 481: loss=1.045, rw_mean=0.070, rw_bound=0.406, batch=231
# 482: loss=1.047, rw_mean=0.060, rw_bound=0.430, batch=172
# 483: loss=1.036, rw_mean=0.090, rw_bound=0.000, batch=181
# 484: loss=1.035, rw_mean=0.060, rw_bound=0.000, batch=187
# 485: loss=1.034, rw_mean=0.030, rw_bound=0.000, batch=190
# 486: loss=1.033, rw_mean=0.080, rw_bound=0.000, batch=198
# 487: loss=1.034, rw_mean=0.090, rw_bound=0.000, batch=207
# 488: loss=1.036, rw_mean=0.040, rw_bound=0.000, batch=211
# 489: loss=1.035, rw_mean=0.060, rw_bound=0.000, batch=217
# 490: loss=1.035, rw_mean=0.090, rw_bound=0.132, batch=222
# 491: loss=1.032, rw_mean=0.030, rw_bound=0.014, batch=225
# 492: loss=1.030, rw_mean=0.070, rw_bound=0.135, batch=225
# 493: loss=1.030, rw_mean=0.050, rw_bound=0.167, batch=225
# 494: loss=1.029, rw_mean=0.060, rw_bound=0.206, batch=223
# 495: loss=1.031, rw_mean=0.040, rw_bound=0.142, batch=226
# 496: loss=1.032, rw_mean=0.070, rw_bound=0.229, batch=224
# 497: loss=1.031, rw_mean=0.040, rw_bound=0.176, batch=227
# 498: loss=1.030, rw_mean=0.040, rw_bound=0.168, batch=229
# 499: loss=1.031, rw_mean=0.090, rw_bound=0.254, batch=229
# 500: loss=1.040, rw_mean=0.100, rw_bound=0.282, batch=219
# 501: loss=1.037, rw_mean=0.050, rw_bound=0.125, batch=223
# 502: loss=1.037, rw_mean=0.060, rw_bound=0.220, batch=226
# 503: loss=1.033, rw_mean=0.040, rw_bound=0.207, batch=228
# 504: loss=1.034, rw_mean=0.040, rw_bound=0.254, batch=228
# 505: loss=1.034, rw_mean=0.070, rw_bound=0.257, batch=229
# 506: loss=1.034, rw_mean=0.050, rw_bound=0.282, batch=229
# 507: loss=1.034, rw_mean=0.040, rw_bound=0.263, batch=230
# 508: loss=1.037, rw_mean=0.030, rw_bound=0.314, batch=225
# 509: loss=1.037, rw_mean=0.060, rw_bound=0.253, batch=227
# 510: loss=1.036, rw_mean=0.030, rw_bound=0.216, batch=229
# 511: loss=1.038, rw_mean=0.060, rw_bound=0.328, batch=230
# 512: loss=1.034, rw_mean=0.080, rw_bound=0.349, batch=219
# 513: loss=1.040, rw_mean=0.090, rw_bound=0.387, batch=211
# 514: loss=1.040, rw_mean=0.060, rw_bound=0.000, batch=217
# 515: loss=1.044, rw_mean=0.020, rw_bound=0.000, batch=219
# 516: loss=1.040, rw_mean=0.080, rw_bound=0.229, batch=222
# 517: loss=1.038, rw_mean=0.080, rw_bound=0.282, batch=224
# 518: loss=1.037, rw_mean=0.070, rw_bound=0.308, batch=227
# 519: loss=1.038, rw_mean=0.020, rw_bound=0.203, batch=229
# 520: loss=1.038, rw_mean=0.070, rw_bound=0.314, batch=229
# 521: loss=1.038, rw_mean=0.070, rw_bound=0.263, batch=230
# 522: loss=1.038, rw_mean=0.050, rw_bound=0.349, batch=226
# 523: loss=1.040, rw_mean=0.040, rw_bound=0.175, batch=228
# 524: loss=1.038, rw_mean=0.070, rw_bound=0.353, batch=229
# 525: loss=1.037, rw_mean=0.050, rw_bound=0.364, batch=230
# 526: loss=1.037, rw_mean=0.130, rw_bound=0.387, batch=226
# 527: loss=1.037, rw_mean=0.090, rw_bound=0.331, batch=228
# 528: loss=1.037, rw_mean=0.080, rw_bound=0.317, batch=229
# 529: loss=1.037, rw_mean=0.030, rw_bound=0.328, batch=230
# 530: loss=1.036, rw_mean=0.030, rw_bound=0.376, batch=231
# 531: loss=1.041, rw_mean=0.020, rw_bound=0.430, batch=201
# 532: loss=1.038, rw_mean=0.070, rw_bound=0.000, batch=208
# 533: loss=1.038, rw_mean=0.090, rw_bound=0.126, batch=215
# 534: loss=1.037, rw_mean=0.080, rw_bound=0.167, batch=218
# 535: loss=1.035, rw_mean=0.040, rw_bound=0.014, batch=222
# 536: loss=1.033, rw_mean=0.060, rw_bound=0.161, batch=225
# 537: loss=1.038, rw_mean=0.070, rw_bound=0.206, batch=226
# 538: loss=1.042, rw_mean=0.050, rw_bound=0.229, batch=226
# 539: loss=1.041, rw_mean=0.040, rw_bound=0.220, batch=228
# 540: loss=1.038, rw_mean=0.100, rw_bound=0.282, batch=227
# 541: loss=1.035, rw_mean=0.090, rw_bound=0.314, batch=224
# 542: loss=1.035, rw_mean=0.070, rw_bound=0.249, batch=227
# 543: loss=1.035, rw_mean=0.080, rw_bound=0.249, batch=229
# 544: loss=1.037, rw_mean=0.060, rw_bound=0.295, batch=230
# 545: loss=1.032, rw_mean=0.060, rw_bound=0.349, batch=226
# 546: loss=1.030, rw_mean=0.080, rw_bound=0.298, batch=228
# 547: loss=1.033, rw_mean=0.070, rw_bound=0.387, batch=219
# 548: loss=1.034, rw_mean=0.080, rw_bound=0.324, batch=223
# 549: loss=1.033, rw_mean=0.060, rw_bound=0.184, batch=226
# 550: loss=1.034, rw_mean=0.100, rw_bound=0.387, batch=224
# 551: loss=1.033, rw_mean=0.090, rw_bound=0.345, batch=227
# 552: loss=1.035, rw_mean=0.080, rw_bound=0.387, batch=227
# 553: loss=1.032, rw_mean=0.030, rw_bound=0.102, batch=229
# 554: loss=1.035, rw_mean=0.110, rw_bound=0.387, batch=229
# 555: loss=1.035, rw_mean=0.050, rw_bound=0.381, batch=230
# 556: loss=1.036, rw_mean=0.070, rw_bound=0.430, batch=219
# 557: loss=1.035, rw_mean=0.030, rw_bound=0.000, batch=222
# 558: loss=1.033, rw_mean=0.090, rw_bound=0.263, batch=225
# 559: loss=1.031, rw_mean=0.080, rw_bound=0.289, batch=227
# 560: loss=1.031, rw_mean=0.040, rw_bound=0.288, batch=229
# 561: loss=1.030, rw_mean=0.080, rw_bound=0.349, batch=229
# 562: loss=1.036, rw_mean=0.080, rw_bound=0.387, batch=228
# 563: loss=1.035, rw_mean=0.030, rw_bound=0.289, batch=229
# 564: loss=1.035, rw_mean=0.090, rw_bound=0.387, batch=229
# 565: loss=1.035, rw_mean=0.090, rw_bound=0.405, batch=230
# 566: loss=1.033, rw_mean=0.070, rw_bound=0.430, batch=230
# 567: loss=1.034, rw_mean=0.060, rw_bound=0.356, batch=231
# 568: loss=1.043, rw_mean=0.060, rw_bound=0.478, batch=155
# 569: loss=1.035, rw_mean=0.090, rw_bound=0.000, batch=164
# 570: loss=1.034, rw_mean=0.100, rw_bound=0.000, batch=174
# 571: loss=1.029, rw_mean=0.080, rw_bound=0.000, batch=182
# 572: loss=1.029, rw_mean=0.070, rw_bound=0.000, batch=189
# 573: loss=1.027, rw_mean=0.060, rw_bound=0.000, batch=195
# 574: loss=1.028, rw_mean=0.100, rw_bound=0.000, batch=205
# 575: loss=1.029, rw_mean=0.070, rw_bound=0.000, batch=212
# 576: loss=1.026, rw_mean=0.040, rw_bound=0.000, batch=216
# 577: loss=1.024, rw_mean=0.050, rw_bound=0.029, batch=221
# 578: loss=1.026, rw_mean=0.070, rw_bound=0.109, batch=223
# 579: loss=1.024, rw_mean=0.120, rw_bound=0.167, batch=225
# 580: loss=1.024, rw_mean=0.070, rw_bound=0.206, batch=225
# 581: loss=1.023, rw_mean=0.020, rw_bound=0.046, batch=227
# 582: loss=1.020, rw_mean=0.050, rw_bound=0.229, batch=224
# 583: loss=1.018, rw_mean=0.050, rw_bound=0.254, batch=219
# 584: loss=1.018, rw_mean=0.010, rw_bound=0.000, batch=220
# 585: loss=1.018, rw_mean=0.060, rw_bound=0.185, batch=224
# 586: loss=1.017, rw_mean=0.090, rw_bound=0.282, batch=220
# 587: loss=1.016, rw_mean=0.050, rw_bound=0.082, batch=224
# 588: loss=1.017, rw_mean=0.080, rw_bound=0.206, batch=226
# 589: loss=1.016, rw_mean=0.050, rw_bound=0.282, batch=227
# 590: loss=1.015, rw_mean=0.070, rw_bound=0.308, batch=229
# 591: loss=1.019, rw_mean=0.100, rw_bound=0.314, batch=220
# 592: loss=1.018, rw_mean=0.080, rw_bound=0.259, batch=224
# 593: loss=1.018, rw_mean=0.050, rw_bound=0.142, batch=227
# 594: loss=1.018, rw_mean=0.010, rw_bound=0.000, batch=228
# 595: loss=1.016, rw_mean=0.070, rw_bound=0.286, batch=229
# 596: loss=1.017, rw_mean=0.030, rw_bound=0.237, batch=230
# 597: loss=1.017, rw_mean=0.090, rw_bound=0.338, batch=231
# 598: loss=1.013, rw_mean=0.050, rw_bound=0.349, batch=207
# 599: loss=1.016, rw_mean=0.100, rw_bound=0.080, batch=214
# 600: loss=1.012, rw_mean=0.050, rw_bound=0.000, batch=219
# 601: loss=1.012, rw_mean=0.070, rw_bound=0.182, batch=223
# 602: loss=1.014, rw_mean=0.080, rw_bound=0.206, batch=222
# 603: loss=1.017, rw_mean=0.090, rw_bound=0.254, batch=224
# 604: loss=1.017, rw_mean=0.060, rw_bound=0.311, batch=227
# 605: loss=1.013, rw_mean=0.090, rw_bound=0.314, batch=226
# 606: loss=1.013, rw_mean=0.100, rw_bound=0.349, batch=224
# 607: loss=1.013, rw_mean=0.050, rw_bound=0.296, batch=227
# 608: loss=1.013, rw_mean=0.060, rw_bound=0.314, batch=228
# 609: loss=1.014, rw_mean=0.070, rw_bound=0.349, batch=226
# 610: loss=1.013, rw_mean=0.060, rw_bound=0.368, batch=228
# 611: loss=1.031, rw_mean=0.110, rw_bound=0.387, batch=204
# 612: loss=1.031, rw_mean=0.090, rw_bound=0.089, batch=213
# 613: loss=1.033, rw_mean=0.100, rw_bound=0.198, batch=219
# 614: loss=1.029, rw_mean=0.060, rw_bound=0.206, batch=221
# 615: loss=1.026, rw_mean=0.040, rw_bound=0.229, batch=224
# 616: loss=1.027, rw_mean=0.060, rw_bound=0.249, batch=227
# 617: loss=1.026, rw_mean=0.040, rw_bound=0.245, batch=229
# 618: loss=1.027, rw_mean=0.090, rw_bound=0.282, batch=229
# 619: loss=1.029, rw_mean=0.010, rw_bound=0.026, batch=230
# 620: loss=1.028, rw_mean=0.080, rw_bound=0.314, batch=230
# 621: loss=1.028, rw_mean=0.140, rw_bound=0.349, batch=226
# 622: loss=1.029, rw_mean=0.050, rw_bound=0.331, batch=228
# 623: loss=1.029, rw_mean=0.070, rw_bound=0.317, batch=229
# 624: loss=1.027, rw_mean=0.100, rw_bound=0.364, batch=230
# 625: loss=1.026, rw_mean=0.030, rw_bound=0.338, batch=231
# 626: loss=1.026, rw_mean=0.050, rw_bound=0.349, batch=230
# 627: loss=1.026, rw_mean=0.040, rw_bound=0.304, batch=231
# 628: loss=1.029, rw_mean=0.080, rw_bound=0.387, batch=227
# 629: loss=1.027, rw_mean=0.100, rw_bound=0.387, batch=228
# 630: loss=1.028, rw_mean=0.120, rw_bound=0.392, batch=229
# 631: loss=1.027, rw_mean=0.080, rw_bound=0.405, batch=230
# 632: loss=1.035, rw_mean=0.110, rw_bound=0.430, batch=196
# 633: loss=1.030, rw_mean=0.090, rw_bound=0.000, batch=205
# 634: loss=1.032, rw_mean=0.070, rw_bound=0.000, batch=212
# 635: loss=1.036, rw_mean=0.050, rw_bound=0.000, batch=217
# 636: loss=1.033, rw_mean=0.030, rw_bound=0.000, batch=220
# 637: loss=1.033, rw_mean=0.050, rw_bound=0.073, batch=224
# 638: loss=1.029, rw_mean=0.040, rw_bound=0.106, batch=227
# 639: loss=1.036, rw_mean=0.060, rw_bound=0.147, batch=229
# 640: loss=1.034, rw_mean=0.070, rw_bound=0.206, batch=228
# 641: loss=1.030, rw_mean=0.120, rw_bound=0.282, batch=226
# 642: loss=1.031, rw_mean=0.060, rw_bound=0.314, batch=222
# 643: loss=1.030, rw_mean=0.030, rw_bound=0.030, batch=225
# 644: loss=1.029, rw_mean=0.050, rw_bound=0.234, batch=227
# 645: loss=1.027, rw_mean=0.110, rw_bound=0.349, batch=224
# 646: loss=1.025, rw_mean=0.050, rw_bound=0.334, batch=227
# 647: loss=1.022, rw_mean=0.040, rw_bound=0.263, batch=229
# 648: loss=1.030, rw_mean=0.080, rw_bound=0.387, batch=220
# 649: loss=1.028, rw_mean=0.060, rw_bound=0.314, batch=223
# 650: loss=1.024, rw_mean=0.030, rw_bound=0.100, batch=226
# 651: loss=1.029, rw_mean=0.090, rw_bound=0.298, batch=228
# 652: loss=1.030, rw_mean=0.080, rw_bound=0.349, batch=227
# 653: loss=1.029, rw_mean=0.050, rw_bound=0.314, batch=228
# 654: loss=1.028, rw_mean=0.070, rw_bound=0.387, batch=227
# 655: loss=1.029, rw_mean=0.120, rw_bound=0.422, batch=229
# 656: loss=1.031, rw_mean=0.060, rw_bound=0.405, batch=230
# 657: loss=1.030, rw_mean=0.060, rw_bound=0.376, batch=231
# 658: loss=1.030, rw_mean=0.050, rw_bound=0.387, batch=231
# 659: loss=1.030, rw_mean=0.040, rw_bound=0.282, batch=231
# 660: loss=1.028, rw_mean=0.070, rw_bound=0.430, batch=220
# 661: loss=1.027, rw_mean=0.080, rw_bound=0.274, batch=224
# 662: loss=1.025, rw_mean=0.060, rw_bound=0.377, batch=227
# 663: loss=1.026, rw_mean=0.070, rw_bound=0.387, batch=227
# 664: loss=1.025, rw_mean=0.050, rw_bound=0.452, batch=229
# 665: loss=1.025, rw_mean=0.050, rw_bound=0.343, batch=230
# 666: loss=1.024, rw_mean=0.070, rw_bound=0.376, batch=231
# 667: loss=1.023, rw_mean=0.020, rw_bound=0.387, batch=231
# 668: loss=1.022, rw_mean=0.080, rw_bound=0.430, batch=231
# 669: loss=1.028, rw_mean=0.080, rw_bound=0.478, batch=195
# 670: loss=1.024, rw_mean=0.030, rw_bound=0.000, batch=198
# 671: loss=1.023, rw_mean=0.070, rw_bound=0.000, batch=205
# 672: loss=1.022, rw_mean=0.060, rw_bound=0.000, batch=211
# 673: loss=1.019, rw_mean=0.080, rw_bound=0.089, batch=217
# 674: loss=1.024, rw_mean=0.080, rw_bound=0.182, batch=222
# 675: loss=1.024, rw_mean=0.030, rw_bound=0.056, batch=225
# 676: loss=1.026, rw_mean=0.070, rw_bound=0.254, batch=226
# 677: loss=1.028, rw_mean=0.050, rw_bound=0.282, batch=225
# 678: loss=1.027, rw_mean=0.080, rw_bound=0.314, batch=224
# 679: loss=1.028, rw_mean=0.120, rw_bound=0.349, batch=215
# 680: loss=1.029, rw_mean=0.130, rw_bound=0.314, batch=218
# 681: loss=1.033, rw_mean=0.060, rw_bound=0.100, batch=222
# 682: loss=1.030, rw_mean=0.080, rw_bound=0.292, batch=225
# 683: loss=1.031, rw_mean=0.040, rw_bound=0.289, batch=227
# 684: loss=1.030, rw_mean=0.040, rw_bound=0.278, batch=229
# 685: loss=1.032, rw_mean=0.080, rw_bound=0.314, batch=228
# 686: loss=1.028, rw_mean=0.050, rw_bound=0.349, batch=228
# 687: loss=1.025, rw_mean=0.090, rw_bound=0.387, batch=222
# 688: loss=1.024, rw_mean=0.060, rw_bound=0.263, batch=225
# 689: loss=1.025, rw_mean=0.030, rw_bound=0.170, batch=227
# 690: loss=1.029, rw_mean=0.050, rw_bound=0.206, batch=228
# 691: loss=1.028, rw_mean=0.100, rw_bound=0.293, batch=229
# 692: loss=1.031, rw_mean=0.080, rw_bound=0.430, batch=214
# 693: loss=1.031, rw_mean=0.050, rw_bound=0.000, batch=219
# 694: loss=1.031, rw_mean=0.030, rw_bound=0.000, batch=222
# 695: loss=1.031, rw_mean=0.120, rw_bound=0.324, batch=225
# 696: loss=1.031, rw_mean=0.040, rw_bound=0.296, batch=227
# 697: loss=1.030, rw_mean=0.050, rw_bound=0.349, batch=224
# 698: loss=1.030, rw_mean=0.090, rw_bound=0.377, batch=227
# 699: loss=1.029, rw_mean=0.090, rw_bound=0.380, batch=229
# 700: loss=1.027, rw_mean=0.090, rw_bound=0.387, batch=229
# 701: loss=1.030, rw_mean=0.050, rw_bound=0.430, batch=222
# 702: loss=1.026, rw_mean=0.040, rw_bound=0.061, batch=225
# 703: loss=1.031, rw_mean=0.050, rw_bound=0.229, batch=226
# 704: loss=1.029, rw_mean=0.090, rw_bound=0.331, batch=228
# 705: loss=1.027, rw_mean=0.040, rw_bound=0.349, batch=228
# 706: loss=1.026, rw_mean=0.040, rw_bound=0.206, batch=229
# 707: loss=1.028, rw_mean=0.060, rw_bound=0.387, batch=227
# 708: loss=1.029, rw_mean=0.030, rw_bound=0.249, batch=229
# 709: loss=1.027, rw_mean=0.060, rw_bound=0.364, batch=230
# 710: loss=1.027, rw_mean=0.030, rw_bound=0.418, batch=231
# 711: loss=1.027, rw_mean=0.080, rw_bound=0.387, batch=231
# 712: loss=1.027, rw_mean=0.050, rw_bound=0.387, batch=231
# 713: loss=1.027, rw_mean=0.050, rw_bound=0.387, batch=231
# 714: loss=1.027, rw_mean=0.060, rw_bound=0.349, batch=231
# 715: loss=1.027, rw_mean=0.030, rw_bound=0.349, batch=231
# 716: loss=1.026, rw_mean=0.090, rw_bound=0.430, batch=231
# 717: loss=1.026, rw_mean=0.050, rw_bound=0.314, batch=231
# 718: loss=1.029, rw_mean=0.090, rw_bound=0.478, batch=208
# 719: loss=1.028, rw_mean=0.120, rw_bound=0.314, batch=212
# 720: loss=1.024, rw_mean=0.100, rw_bound=0.292, batch=218
# 721: loss=1.026, rw_mean=0.110, rw_bound=0.349, batch=220
# 722: loss=1.023, rw_mean=0.090, rw_bound=0.329, batch=224
# 723: loss=1.021, rw_mean=0.030, rw_bound=0.150, batch=227
# 724: loss=1.020, rw_mean=0.080, rw_bound=0.349, batch=228
# 725: loss=1.019, rw_mean=0.070, rw_bound=0.353, batch=229
# 726: loss=1.022, rw_mean=0.090, rw_bound=0.387, batch=225
# 727: loss=1.020, rw_mean=0.050, rw_bound=0.216, batch=227
# 728: loss=1.022, rw_mean=0.110, rw_bound=0.342, batch=229
# 729: loss=1.021, rw_mean=0.030, rw_bound=0.278, batch=230
# 730: loss=1.022, rw_mean=0.020, rw_bound=0.338, batch=231
# 731: loss=1.022, rw_mean=0.010, rw_bound=0.349, batch=230
# 732: loss=1.022, rw_mean=0.070, rw_bound=0.418, batch=231
# 733: loss=1.024, rw_mean=0.040, rw_bound=0.430, batch=223
# 734: loss=1.025, rw_mean=0.040, rw_bound=0.301, batch=226
# 735: loss=1.025, rw_mean=0.070, rw_bound=0.349, batch=227
# 736: loss=1.026, rw_mean=0.050, rw_bound=0.198, batch=229
# 737: loss=1.024, rw_mean=0.060, rw_bound=0.343, batch=230
# 738: loss=1.023, rw_mean=0.080, rw_bound=0.387, batch=230
# 739: loss=1.023, rw_mean=0.050, rw_bound=0.313, batch=231
# 740: loss=1.023, rw_mean=0.080, rw_bound=0.430, batch=228
# 741: loss=1.024, rw_mean=0.130, rw_bound=0.478, batch=231
# 742: loss=1.027, rw_mean=0.060, rw_bound=0.478, batch=221
# 743: loss=1.027, rw_mean=0.050, rw_bound=0.206, batch=224
# 744: loss=1.030, rw_mean=0.090, rw_bound=0.387, batch=225
# 745: loss=1.030, rw_mean=0.090, rw_bound=0.365, batch=227
# 746: loss=1.027, rw_mean=0.020, rw_bound=0.279, batch=229
# 747: loss=1.026, rw_mean=0.030, rw_bound=0.430, batch=225
# 748: loss=1.026, rw_mean=0.080, rw_bound=0.396, batch=227
# 749: loss=1.024, rw_mean=0.080, rw_bound=0.430, batch=228
# 750: loss=1.024, rw_mean=0.030, rw_bound=0.353, batch=229
# 751: loss=1.023, rw_mean=0.080, rw_bound=0.405, batch=230
# 752: loss=1.023, rw_mean=0.070, rw_bound=0.430, batch=230
# 753: loss=1.022, rw_mean=0.070, rw_bound=0.464, batch=231
# 754: loss=1.022, rw_mean=0.090, rw_bound=0.430, batch=231
# 755: loss=1.022, rw_mean=0.050, rw_bound=0.430, batch=231
# 756: loss=1.022, rw_mean=0.030, rw_bound=0.349, batch=231
# 757: loss=1.023, rw_mean=0.050, rw_bound=0.478, batch=225
# 758: loss=1.023, rw_mean=0.050, rw_bound=0.430, batch=226
# 759: loss=1.025, rw_mean=0.070, rw_bound=0.433, batch=228
# 760: loss=1.023, rw_mean=0.070, rw_bound=0.321, batch=229
# 761: loss=1.026, rw_mean=0.100, rw_bound=0.478, batch=231
# 762: loss=1.024, rw_mean=0.050, rw_bound=0.478, batch=228
# 763: loss=1.027, rw_mean=0.100, rw_bound=0.484, batch=229
# 764: loss=1.028, rw_mean=0.040, rw_bound=0.295, batch=230
# 765: loss=1.030, rw_mean=0.050, rw_bound=0.395, batch=231
# 766: loss=1.028, rw_mean=0.090, rw_bound=0.478, batch=231
# 768: loss=0.994, rw_mean=0.090, rw_bound=0.000, batch=9
# 769: loss=0.971, rw_mean=0.040, rw_bound=0.000, batch=13
# 770: loss=1.004, rw_mean=0.040, rw_bound=0.000, batch=17
# 771: loss=1.006, rw_mean=0.060, rw_bound=0.000, batch=23
# 772: loss=1.027, rw_mean=0.070, rw_bound=0.000, batch=30
# 773: loss=1.019, rw_mean=0.020, rw_bound=0.000, batch=32
# 774: loss=1.017, rw_mean=0.030, rw_bound=0.000, batch=35
# 775: loss=1.008, rw_mean=0.070, rw_bound=0.000, batch=42
# 776: loss=1.005, rw_mean=0.110, rw_bound=0.000, batch=53
# 777: loss=1.005, rw_mean=0.080, rw_bound=0.000, batch=61
# 778: loss=0.997, rw_mean=0.080, rw_bound=0.000, batch=69
# 779: loss=0.997, rw_mean=0.080, rw_bound=0.000, batch=77
# 780: loss=0.993, rw_mean=0.090, rw_bound=0.000, batch=86
# 781: loss=0.998, rw_mean=0.090, rw_bound=0.000, batch=95
# 782: loss=0.992, rw_mean=0.070, rw_bound=0.000, batch=102
# 783: loss=0.988, rw_mean=0.150, rw_bound=0.000, batch=117
# 784: loss=0.989, rw_mean=0.040, rw_bound=0.000, batch=121
# 785: loss=0.982, rw_mean=0.080, rw_bound=0.000, batch=129
# 786: loss=0.977, rw_mean=0.070, rw_bound=0.000, batch=136
# 787: loss=0.980, rw_mean=0.090, rw_bound=0.000, batch=145
# 788: loss=0.973, rw_mean=0.080, rw_bound=0.000, batch=153
# 789: loss=0.973, rw_mean=0.110, rw_bound=0.000, batch=164
# 790: loss=0.974, rw_mean=0.050, rw_bound=0.000, batch=169
# 791: loss=0.968, rw_mean=0.130, rw_bound=0.000, batch=182
# 792: loss=0.965, rw_mean=0.070, rw_bound=0.000, batch=189
# 793: loss=0.966, rw_mean=0.090, rw_bound=0.000, batch=198
# 794: loss=0.961, rw_mean=0.120, rw_bound=0.023, batch=208
# 795: loss=0.962, rw_mean=0.100, rw_bound=0.031, batch=215
# 796: loss=0.962, rw_mean=0.060, rw_bound=0.034, batch=219
# 797: loss=0.957, rw_mean=0.100, rw_bound=0.061, batch=223
# 798: loss=0.958, rw_mean=0.110, rw_bound=0.080, batch=224
# 799: loss=0.961, rw_mean=0.110, rw_bound=0.097, batch=227
# 800: loss=0.964, rw_mean=0.070, rw_bound=0.098, batch=226
# 801: loss=0.962, rw_mean=0.090, rw_bound=0.122, batch=226
# 802: loss=0.962, rw_mean=0.070, rw_bound=0.135, batch=225
# 803: loss=0.962, rw_mean=0.050, rw_bound=0.150, batch=225
# 804: loss=0.963, rw_mean=0.080, rw_bound=0.167, batch=220
# 805: loss=0.963, rw_mean=0.120, rw_bound=0.180, batch=224
# 806: loss=0.960, rw_mean=0.080, rw_bound=0.185, batch=214
# 807: loss=0.953, rw_mean=0.110, rw_bound=0.206, batch=201
# 808: loss=0.951, rw_mean=0.100, rw_bound=0.080, batch=210
# 809: loss=0.951, rw_mean=0.090, rw_bound=0.131, batch=217
# 810: loss=0.950, rw_mean=0.110, rw_bound=0.202, batch=222
# 811: loss=0.940, rw_mean=0.090, rw_bound=0.229, batch=204
# 812: loss=0.942, rw_mean=0.050, rw_bound=0.000, batch=209
# 813: loss=0.938, rw_mean=0.090, rw_bound=0.133, batch=216
# 814: loss=0.936, rw_mean=0.060, rw_bound=0.068, batch=221
# 815: loss=0.933, rw_mean=0.050, rw_bound=0.072, batch=224
# 816: loss=0.930, rw_mean=0.100, rw_bound=0.229, batch=225
# 817: loss=0.934, rw_mean=0.080, rw_bound=0.254, batch=195
# 818: loss=0.933, rw_mean=0.080, rw_bound=0.000, batch=203
# 819: loss=0.936, rw_mean=0.080, rw_bound=0.000, batch=211
# 820: loss=0.932, rw_mean=0.060, rw_bound=0.000, batch=217
# 821: loss=0.927, rw_mean=0.130, rw_bound=0.126, batch=222
# 822: loss=0.923, rw_mean=0.120, rw_bound=0.172, batch=225
# 823: loss=0.923, rw_mean=0.070, rw_bound=0.229, batch=226
# 824: loss=0.934, rw_mean=0.150, rw_bound=0.282, batch=187
# 825: loss=0.926, rw_mean=0.070, rw_bound=0.000, batch=194
# 826: loss=0.923, rw_mean=0.100, rw_bound=0.000, batch=204
# 827: loss=0.917, rw_mean=0.100, rw_bound=0.067, batch=213
# 828: loss=0.918, rw_mean=0.090, rw_bound=0.085, batch=219
# 829: loss=0.926, rw_mean=0.140, rw_bound=0.167, batch=216
# 830: loss=0.922, rw_mean=0.070, rw_bound=0.097, batch=221
# ...
# 17431: loss=0.152, rw_mean=0.380, rw_bound=0.150, batch=200
# 17432: loss=0.153, rw_mean=0.490, rw_bound=0.157, batch=210
# 17433: loss=0.152, rw_mean=0.370, rw_bound=0.180, batch=217
# 17434: loss=0.150, rw_mean=0.470, rw_bound=0.185, batch=220
# 17435: loss=0.150, rw_mean=0.500, rw_bound=0.229, batch=195
# 17436: loss=0.150, rw_mean=0.430, rw_bound=0.185, batch=204
# 17437: loss=0.150, rw_mean=0.410, rw_bound=0.229, batch=212
# 17438: loss=0.154, rw_mean=0.410, rw_bound=0.254, batch=189
# 17439: loss=0.153, rw_mean=0.430, rw_bound=0.206, batch=201
# 17440: loss=0.152, rw_mean=0.360, rw_bound=0.167, batch=209
# 17441: loss=0.151, rw_mean=0.490, rw_bound=0.229, batch=215
# 17442: loss=0.150, rw_mean=0.440, rw_bound=0.254, batch=213
# 17443: loss=0.151, rw_mean=0.400, rw_bound=0.229, batch=218
# 17444: loss=0.153, rw_mean=0.510, rw_bound=0.282, batch=184
# 17445: loss=0.149, rw_mean=0.440, rw_bound=0.229, batch=197
# 17446: loss=0.149, rw_mean=0.520, rw_bound=0.167, batch=207
# 17447: loss=0.153, rw_mean=0.520, rw_bound=0.224, batch=215
# 17448: loss=0.156, rw_mean=0.470, rw_bound=0.229, batch=219
# 17449: loss=0.156, rw_mean=0.390, rw_bound=0.254, batch=222
# 17450: loss=0.159, rw_mean=0.490, rw_bound=0.245, batch=225
# 17451: loss=0.157, rw_mean=0.390, rw_bound=0.282, batch=223
# 17452: loss=0.153, rw_mean=0.430, rw_bound=0.314, batch=179
# 17453: loss=0.157, rw_mean=0.480, rw_bound=0.174, batch=195
# 17454: loss=0.154, rw_mean=0.370, rw_bound=0.170, batch=206
# 17455: loss=0.150, rw_mean=0.430, rw_bound=0.206, batch=212
# 17456: loss=0.152, rw_mean=0.430, rw_bound=0.229, batch=214
# 17457: loss=0.150, rw_mean=0.390, rw_bound=0.254, batch=213
# 17458: loss=0.150, rw_mean=0.400, rw_bound=0.244, batch=219
# 17459: loss=0.151, rw_mean=0.530, rw_bound=0.282, batch=215
# 17460: loss=0.154, rw_mean=0.500, rw_bound=0.314, batch=215
# 17461: loss=0.152, rw_mean=0.370, rw_bound=0.321, batch=220
# 17462: loss=0.147, rw_mean=0.490, rw_bound=0.349, batch=165
# 17463: loss=0.143, rw_mean=0.470, rw_bound=0.101, batch=185
# 17464: loss=0.143, rw_mean=0.540, rw_bound=0.150, batch=197
# 17465: loss=0.140, rw_mean=0.490, rw_bound=0.135, batch=207
# 17466: loss=0.143, rw_mean=0.530, rw_bound=0.206, batch=213
# 17467: loss=0.145, rw_mean=0.400, rw_bound=0.229, batch=215
# 17468: loss=0.150, rw_mean=0.420, rw_bound=0.254, batch=208
# 17469: loss=0.149, rw_mean=0.550, rw_bound=0.257, batch=215
# 17470: loss=0.146, rw_mean=0.440, rw_bound=0.260, batch=220
# 17471: loss=0.146, rw_mean=0.560, rw_bound=0.282, batch=214
# 17472: loss=0.146, rw_mean=0.440, rw_bound=0.206, batch=219
# 17473: loss=0.145, rw_mean=0.510, rw_bound=0.250, batch=223
# 17474: loss=0.146, rw_mean=0.460, rw_bound=0.282, batch=224
# 17475: loss=0.149, rw_mean=0.390, rw_bound=0.314, batch=217
# 17476: loss=0.149, rw_mean=0.420, rw_bound=0.254, batch=221
# 17477: loss=0.147, rw_mean=0.440, rw_bound=0.349, batch=212
# 17478: loss=0.150, rw_mean=0.460, rw_bound=0.282, batch=216
# 17479: loss=0.149, rw_mean=0.400, rw_bound=0.314, batch=217
# 17480: loss=0.149, rw_mean=0.470, rw_bound=0.335, batch=222
# 17481: loss=0.148, rw_mean=0.440, rw_bound=0.283, batch=225
# 17482: loss=0.147, rw_mean=0.610, rw_bound=0.349, batch=225
# 17483: loss=0.144, rw_mean=0.540, rw_bound=0.387, batch=149
# 17484: loss=0.137, rw_mean=0.500, rw_bound=0.097, batch=174
# 17485: loss=0.146, rw_mean=0.420, rw_bound=0.109, batch=190
# 17486: loss=0.139, rw_mean=0.480, rw_bound=0.135, batch=201
# 17487: loss=0.141, rw_mean=0.430, rw_bound=0.150, batch=209
# 17488: loss=0.138, rw_mean=0.420, rw_bound=0.167, batch=211
# 17489: loss=0.145, rw_mean=0.460, rw_bound=0.185, batch=213
# 17490: loss=0.147, rw_mean=0.440, rw_bound=0.229, batch=213
# 17491: loss=0.146, rw_mean=0.460, rw_bound=0.244, batch=219
# 17492: loss=0.142, rw_mean=0.480, rw_bound=0.254, batch=213
# 17493: loss=0.143, rw_mean=0.520, rw_bound=0.271, batch=219
# 17494: loss=0.143, rw_mean=0.400, rw_bound=0.282, batch=214
# 17495: loss=0.146, rw_mean=0.470, rw_bound=0.254, batch=218
# 17496: loss=0.145, rw_mean=0.350, rw_bound=0.286, batch=222
# 17497: loss=0.146, rw_mean=0.520, rw_bound=0.314, batch=206
# 17498: loss=0.149, rw_mean=0.440, rw_bound=0.241, batch=214
# 17499: loss=0.147, rw_mean=0.370, rw_bound=0.229, batch=219
# 17500: loss=0.145, rw_mean=0.450, rw_bound=0.282, batch=219
# 17501: loss=0.145, rw_mean=0.460, rw_bound=0.295, batch=223
# 17502: loss=0.141, rw_mean=0.510, rw_bound=0.349, batch=205
# 17503: loss=0.140, rw_mean=0.470, rw_bound=0.194, batch=213
# 17504: loss=0.138, rw_mean=0.480, rw_bound=0.282, batch=217
# 17505: loss=0.140, rw_mean=0.430, rw_bound=0.308, batch=222
# 17506: loss=0.143, rw_mean=0.380, rw_bound=0.314, batch=223
# 17507: loss=0.143, rw_mean=0.460, rw_bound=0.349, batch=223
# 17508: loss=0.143, rw_mean=0.560, rw_bound=0.301, batch=226
# 17509: loss=0.142, rw_mean=0.390, rw_bound=0.331, batch=228
# 17510: loss=0.137, rw_mean=0.460, rw_bound=0.387, batch=203
# 17511: loss=0.135, rw_mean=0.450, rw_bound=0.254, batch=211
# 17512: loss=0.135, rw_mean=0.420, rw_bound=0.282, batch=217
# 17513: loss=0.134, rw_mean=0.450, rw_bound=0.202, batch=222
# 17514: loss=0.133, rw_mean=0.460, rw_bound=0.229, batch=223
# 17515: loss=0.135, rw_mean=0.450, rw_bound=0.314, batch=218
# 17516: loss=0.133, rw_mean=0.510, rw_bound=0.349, batch=221
# 17517: loss=0.132, rw_mean=0.460, rw_bound=0.349, batch=224
# 17518: loss=0.133, rw_mean=0.390, rw_bound=0.387, batch=222
# 17519: loss=0.133, rw_mean=0.430, rw_bound=0.349, batch=224
# 17520: loss=0.135, rw_mean=0.450, rw_bound=0.387, batch=226
# 17521: loss=0.134, rw_mean=0.440, rw_bound=0.372, batch=228
# 17522: loss=0.128, rw_mean=0.430, rw_bound=0.430, batch=123
# 17523: loss=0.127, rw_mean=0.390, rw_bound=0.015, batch=156
# 17524: loss=0.124, rw_mean=0.460, rw_bound=0.042, batch=178
# 17525: loss=0.122, rw_mean=0.560, rw_bound=0.073, batch=194
# 17526: loss=0.130, rw_mean=0.460, rw_bound=0.098, batch=205
# 17527: loss=0.130, rw_mean=0.370, rw_bound=0.122, batch=208
# 17528: loss=0.121, rw_mean=0.470, rw_bound=0.150, batch=211
# 17529: loss=0.127, rw_mean=0.460, rw_bound=0.167, batch=216
# 17530: loss=0.127, rw_mean=0.430, rw_bound=0.185, batch=217
# 17531: loss=0.128, rw_mean=0.480, rw_bound=0.206, batch=212
# 17532: loss=0.129, rw_mean=0.440, rw_bound=0.191, batch=218
# 17533: loss=0.127, rw_mean=0.480, rw_bound=0.229, batch=210
# 17534: loss=0.128, rw_mean=0.370, rw_bound=0.254, batch=202
# 17535: loss=0.126, rw_mean=0.450, rw_bound=0.254, batch=210
# 17536: loss=0.128, rw_mean=0.420, rw_bound=0.222, batch=217
# 17537: loss=0.130, rw_mean=0.480, rw_bound=0.282, batch=202
# 17538: loss=0.126, rw_mean=0.380, rw_bound=0.150, batch=210
# 17539: loss=0.125, rw_mean=0.420, rw_bound=0.206, batch=218
# 17540: loss=0.129, rw_mean=0.460, rw_bound=0.208, batch=222
# 17541: loss=0.127, rw_mean=0.430, rw_bound=0.236, batch=225
# 17542: loss=0.126, rw_mean=0.400, rw_bound=0.254, batch=226
# 17543: loss=0.127, rw_mean=0.520, rw_bound=0.282, batch=221
# 17544: loss=0.136, rw_mean=0.380, rw_bound=0.314, batch=203
# 17545: loss=0.134, rw_mean=0.370, rw_bound=0.244, batch=212
# 17546: loss=0.136, rw_mean=0.470, rw_bound=0.282, batch=217
# 17547: loss=0.135, rw_mean=0.520, rw_bound=0.314, batch=217
# 17548: loss=0.134, rw_mean=0.570, rw_bound=0.349, batch=193
# 17549: loss=0.135, rw_mean=0.470, rw_bound=0.282, batch=201
# 17550: loss=0.135, rw_mean=0.540, rw_bound=0.185, batch=210
# 17551: loss=0.134, rw_mean=0.460, rw_bound=0.229, batch=214
# 17552: loss=0.133, rw_mean=0.430, rw_bound=0.282, batch=217
# 17553: loss=0.135, rw_mean=0.520, rw_bound=0.314, batch=219
# 17554: loss=0.133, rw_mean=0.360, rw_bound=0.185, batch=222
# 17555: loss=0.135, rw_mean=0.500, rw_bound=0.254, batch=222
# 17556: loss=0.135, rw_mean=0.440, rw_bound=0.314, batch=224
# 17557: loss=0.136, rw_mean=0.440, rw_bound=0.349, batch=223
# 17558: loss=0.131, rw_mean=0.490, rw_bound=0.387, batch=195
# 17559: loss=0.132, rw_mean=0.520, rw_bound=0.260, batch=206
# 17560: loss=0.132, rw_mean=0.460, rw_bound=0.186, batch=214
# 17561: loss=0.135, rw_mean=0.490, rw_bound=0.280, batch=220
# 17562: loss=0.135, rw_mean=0.470, rw_bound=0.282, batch=220
# 17563: loss=0.137, rw_mean=0.380, rw_bound=0.254, batch=223
# 17564: loss=0.134, rw_mean=0.500, rw_bound=0.314, batch=220
# 17565: loss=0.132, rw_mean=0.500, rw_bound=0.304, batch=224
# 17566: loss=0.130, rw_mean=0.400, rw_bound=0.349, batch=214
# 17567: loss=0.134, rw_mean=0.420, rw_bound=0.384, batch=220
# 17568: loss=0.133, rw_mean=0.470, rw_bound=0.349, batch=223
# 17569: loss=0.131, rw_mean=0.500, rw_bound=0.387, batch=215
# 17570: loss=0.130, rw_mean=0.500, rw_bound=0.266, batch=220
# 17571: loss=0.130, rw_mean=0.500, rw_bound=0.338, batch=224
# 17572: loss=0.130, rw_mean=0.350, rw_bound=0.252, batch=227
# 17573: loss=0.130, rw_mean=0.490, rw_bound=0.380, batch=229
# 17574: loss=0.133, rw_mean=0.440, rw_bound=0.387, batch=228
# 17575: loss=0.133, rw_mean=0.340, rw_bound=0.357, batch=229
# 17576: loss=0.137, rw_mean=0.480, rw_bound=0.430, batch=179
# 17577: loss=0.134, rw_mean=0.470, rw_bound=0.150, batch=194
# 17578: loss=0.133, rw_mean=0.500, rw_bound=0.147, batch=206
# 17579: loss=0.132, rw_mean=0.360, rw_bound=0.158, batch=214
# 17580: loss=0.134, rw_mean=0.450, rw_bound=0.185, batch=216
# 17581: loss=0.135, rw_mean=0.490, rw_bound=0.217, batch=221
# 17582: loss=0.137, rw_mean=0.420, rw_bound=0.229, batch=223
# 17583: loss=0.137, rw_mean=0.490, rw_bound=0.254, batch=221
# 17584: loss=0.136, rw_mean=0.430, rw_bound=0.282, batch=216
# 17585: loss=0.134, rw_mean=0.390, rw_bound=0.298, batch=221
# 17586: loss=0.133, rw_mean=0.420, rw_bound=0.282, batch=223
# 17587: loss=0.138, rw_mean=0.460, rw_bound=0.314, batch=218
# 17588: loss=0.136, rw_mean=0.430, rw_bound=0.317, batch=222
# 17589: loss=0.136, rw_mean=0.400, rw_bound=0.314, batch=224
# 17590: loss=0.138, rw_mean=0.470, rw_bound=0.349, batch=214
# 17591: loss=0.137, rw_mean=0.440, rw_bound=0.384, batch=220
# 17592: loss=0.139, rw_mean=0.470, rw_bound=0.282, batch=222
# 17593: loss=0.138, rw_mean=0.400, rw_bound=0.324, batch=225
# 17594: loss=0.138, rw_mean=0.470, rw_bound=0.356, batch=227
# 17595: loss=0.139, rw_mean=0.410, rw_bound=0.349, batch=228
# 17596: loss=0.139, rw_mean=0.380, rw_bound=0.353, batch=229
# 17597: loss=0.137, rw_mean=0.480, rw_bound=0.387, batch=213
# 17598: loss=0.135, rw_mean=0.440, rw_bound=0.254, batch=218
# 17599: loss=0.137, rw_mean=0.430, rw_bound=0.282, batch=220
# 17600: loss=0.138, rw_mean=0.330, rw_bound=0.296, batch=224
# 17601: loss=0.137, rw_mean=0.430, rw_bound=0.426, batch=227
# 17602: loss=0.136, rw_mean=0.420, rw_bound=0.380, batch=229
# 17603: loss=0.136, rw_mean=0.430, rw_bound=0.405, batch=230
# 17604: loss=0.137, rw_mean=0.450, rw_bound=0.430, batch=207
# 17605: loss=0.139, rw_mean=0.470, rw_bound=0.206, batch=214
# 17606: loss=0.136, rw_mean=0.430, rw_bound=0.252, batch=220
# 17607: loss=0.136, rw_mean=0.440, rw_bound=0.282, batch=223
# 17608: loss=0.136, rw_mean=0.450, rw_bound=0.314, batch=220
# 17609: loss=0.137, rw_mean=0.380, rw_bound=0.282, batch=222
# 17610: loss=0.139, rw_mean=0.370, rw_bound=0.314, batch=224
# 17611: loss=0.139, rw_mean=0.390, rw_bound=0.342, batch=227
# 17612: loss=0.136, rw_mean=0.430, rw_bound=0.349, batch=225
# 17613: loss=0.136, rw_mean=0.510, rw_bound=0.349, batch=225
# 17614: loss=0.135, rw_mean=0.450, rw_bound=0.321, batch=227
# 17615: loss=0.136, rw_mean=0.460, rw_bound=0.387, batch=220
# 17616: loss=0.134, rw_mean=0.450, rw_bound=0.304, batch=224
# 17617: loss=0.135, rw_mean=0.500, rw_bound=0.380, batch=227
# 17618: loss=0.135, rw_mean=0.470, rw_bound=0.387, batch=228
# 17619: loss=0.137, rw_mean=0.410, rw_bound=0.357, batch=229
# 17620: loss=0.135, rw_mean=0.460, rw_bound=0.430, batch=219
# 17621: loss=0.135, rw_mean=0.420, rw_bound=0.349, batch=222
# 17622: loss=0.134, rw_mean=0.460, rw_bound=0.360, batch=225
# 17623: loss=0.134, rw_mean=0.440, rw_bound=0.387, batch=224
# 17624: loss=0.134, rw_mean=0.530, rw_bound=0.430, batch=226
# 17625: loss=0.134, rw_mean=0.390, rw_bound=0.368, batch=228
# 17626: loss=0.134, rw_mean=0.480, rw_bound=0.478, batch=230
# 17627: loss=0.137, rw_mean=0.400, rw_bound=0.406, batch=231
# 17628: loss=0.137, rw_mean=0.380, rw_bound=0.387, batch=231
# 17629: loss=0.134, rw_mean=0.470, rw_bound=0.430, batch=230
# 17630: loss=0.135, rw_mean=0.420, rw_bound=0.451, batch=231
# 17631: loss=0.135, rw_mean=0.410, rw_bound=0.430, batch=231
# 17632: loss=0.132, rw_mean=0.490, rw_bound=0.478, batch=93
# 17633: loss=0.137, rw_mean=0.450, rw_bound=0.001, batch=135
# 17634: loss=0.128, rw_mean=0.520, rw_bound=0.015, batch=164
# 17635: loss=0.126, rw_mean=0.460, rw_bound=0.034, batch=185
# 17636: loss=0.129, rw_mean=0.530, rw_bound=0.047, batch=198
# 17637: loss=0.126, rw_mean=0.530, rw_bound=0.080, batch=206
# 17638: loss=0.119, rw_mean=0.440, rw_bound=0.098, batch=202
# 17639: loss=0.121, rw_mean=0.460, rw_bound=0.109, batch=208
# 17640: loss=0.124, rw_mean=0.460, rw_bound=0.122, batch=213
# 17641: loss=0.129, rw_mean=0.500, rw_bound=0.150, batch=210
# 17642: loss=0.128, rw_mean=0.480, rw_bound=0.167, batch=206
# 17643: loss=0.123, rw_mean=0.410, rw_bound=0.185, batch=199
# 17644: loss=0.123, rw_mean=0.500, rw_bound=0.206, batch=193
# 17645: loss=0.121, rw_mean=0.400, rw_bound=0.150, batch=203
# 17646: loss=0.121, rw_mean=0.430, rw_bound=0.185, batch=210
# 17647: loss=0.125, rw_mean=0.410, rw_bound=0.229, batch=206
# 17648: loss=0.126, rw_mean=0.470, rw_bound=0.241, batch=214
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11944\958278557.py in <module>
#       1 full_batch = []
#       2 for iter_no, batch in enumerate(iterate_batches(
# ----> 3         env, net, BATCH_SIZE)):
#       4     reward_mean = float(np.mean(list(map(
#       5         lambda s: s.reward, batch))))
#
# ~\AppData\Local\Temp\ipykernel_11944\4285254625.py in iterate_batches(env, net, batch_size)
#      11     while True:
#      12         obs_v = torch.FloatTensor([obs])
# ---> 13         act_probs_v = sm(net(obs_v))
#      14         act_probs = act_probs_v.data.numpy()[0]
#      15         action = np.random.choice(len(act_probs), p=act_probs)
#
# d:\aiprojects\deeprl\deeprl\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# ~\AppData\Local\Temp\ipykernel_11944\3537234248.py in forward(self, x)
#       9
#      10     def forward(self, x):
# ---> 11         return self.net(x)
#
# d:\aiprojects\deeprl\deeprl\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# d:\aiprojects\deeprl\deeprl\lib\site-packages\torch\nn\modules\container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# d:\aiprojects\deeprl\deeprl\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# d:\aiprojects\deeprl\deeprl\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      91
#      92     def forward(self, input: Tensor) -> Tensor:
# ---> 93         return F.linear(input, self.weight, self.bias)
#      94
#      95     def extra_repr(self) -> str:
#
# d:\aiprojects\deeprl\deeprl\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1688     if input.dim() == 2 and bias is not None:
#    1689         # fused op is marginally faster
# -> 1690         ret = torch.addmm(bias, input, weight.t())
#    1691     else:
#    1692         output = input.matmul(weight.t())
#
# KeyboardInterrupt:
