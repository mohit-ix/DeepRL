# %%
import random
import gym
import gym.spaces
import gym.wrappers
import gym.envs.toy_text.frozen_lake
from collections import namedtuple
import numpy as np
from tensorboardX import SummaryWriter

import torch
import torch.nn as nn
import torch.optim as optim

# %%
HIDDEN_SIZE = 128
BATCH_SIZE = 100
PERCENTILE = 30
GAMMA = 0.9

# %%
class DiscreteOneHotWrapper(gym.ObservationWrapper):
    def __init__(self, env):
        super(DiscreteOneHotWrapper, self).__init__(env)
        assert isinstance(env.observation_space, gym.spaces.Discrete)
        self.observation_space = gym.spaces.Box(0.0, 1.0, (env.observation_space.n, ), dtype=np.float32)

    def observation(self, observation):
        res = np.copy(self.observation_space.low)
        res[observation] = 1.0
        return res


class Net(nn.Module):
    def __init__(self, obs_size, hidden_size, n_actions):
        super(Net, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_size, hidden_size),
            nn.ReLU(),
            nn.Linear(hidden_size, n_actions)
        )

    def forward(self, x):
        return self.net(x)

# %%
Episode = namedtuple('Episode', field_names=['reward', 'steps'])
EpisodeStep = namedtuple('EpisodeStep', field_names=['observation', 'action'])


def iterate_batches(env, net, batch_size):
    batch = []
    episode_reward = 0.0
    episode_steps = []
    obs = env.reset()
    sm = nn.Softmax(dim=1)
    while True:
        obs_v = torch.FloatTensor([obs])
        act_probs_v = sm(net(obs_v))
        act_probs = act_probs_v.data.numpy()[0]
        action = np.random.choice(len(act_probs), p=act_probs)
        next_obs, reward, is_done, _ = env.step(action)
        episode_reward += reward
        episode_steps.append(EpisodeStep(observation=obs, action=action))
        if is_done:
            batch.append(Episode(reward=episode_reward, steps=episode_steps))
            episode_reward = 0.0
            episode_steps = []
            next_obs = env.reset()
            if len(batch) == batch_size:
                yield batch
                batch = []
        obs = next_obs


def filter_batch(batch, percentile):
    disc_rewards = list(map(lambda s: s.reward * (GAMMA ** len(s.steps)), batch))
    reward_bound = np.percentile(disc_rewards, percentile)

    train_obs = []
    train_act = []
    elite_batch = []
    for example, discounted_reward in zip(batch, disc_rewards):
        if discounted_reward > reward_bound:
            train_obs.extend(map(lambda step: step.observation, example.steps))
            train_act.extend(map(lambda step: step.action, example.steps))
            elite_batch.append(example)

    return elite_batch, train_obs, train_act, reward_bound

# %%
env = gym.envs.toy_text.frozen_lake.FrozenLakeEnv(
    is_slippery=False)
env.spec = gym.spec("FrozenLake-v0")
env = gym.wrappers.TimeLimit(env, max_episode_steps=100)
env = DiscreteOneHotWrapper(env)
# env = gym.wrappers.Monitor(env, directory="mon", force=True)
obs_size = env.observation_space.shape[0]
n_actions = env.action_space.n

net = Net(obs_size, HIDDEN_SIZE, n_actions)
objective = nn.CrossEntropyLoss()
optimizer = optim.Adam(params=net.parameters(), lr=0.001)
writer = SummaryWriter(comment="-frozenlake-nonslippery")

full_batch = []
for iter_no, batch in enumerate(iterate_batches(env, net, BATCH_SIZE)):
    reward_mean = float(np.mean(list(map(lambda s: s.reward, batch))))
    full_batch, obs, acts, reward_bound = filter_batch(full_batch + batch, PERCENTILE)
    if not full_batch:
        continue
    obs_v = torch.FloatTensor(obs)
    acts_v = torch.LongTensor(acts)
    full_batch = full_batch[-500:]

    optimizer.zero_grad()
    action_scores_v = net(obs_v)
    loss_v = objective(action_scores_v, acts_v)
    loss_v.backward()
    optimizer.step()
    print("%d: loss=%.3f, reward_mean=%.3f, reward_bound=%.3f, batch=%d" % (
        iter_no, loss_v.item(), reward_mean, reward_bound, len(full_batch)))
    writer.add_scalar("loss", loss_v.item(), iter_no)
    writer.add_scalar("reward_mean", reward_mean, iter_no)
    writer.add_scalar("reward_bound", reward_bound, iter_no)
    if reward_mean > 0.8:
        print("Solved!")
        break
writer.close()
# Out:
# 0: loss=1.395, reward_mean=0.010, reward_bound=0.000, batch=1
# 1: loss=1.388, reward_mean=0.040, reward_bound=0.000, batch=5
# 2: loss=1.384, reward_mean=0.020, reward_bound=0.000, batch=7
# 3: loss=1.372, reward_mean=0.040, reward_bound=0.000, batch=11
# 4: loss=1.365, reward_mean=0.000, reward_bound=0.000, batch=11
# 5: loss=1.363, reward_mean=0.020, reward_bound=0.000, batch=13
# 6: loss=1.357, reward_mean=0.020, reward_bound=0.000, batch=15
# 7: loss=1.348, reward_mean=0.040, reward_bound=0.000, batch=19
# 8: loss=1.344, reward_mean=0.010, reward_bound=0.000, batch=20
# 9: loss=1.341, reward_mean=0.030, reward_bound=0.000, batch=23
# 10: loss=1.340, reward_mean=0.030, reward_bound=0.000, batch=26
# 11: loss=1.337, reward_mean=0.040, reward_bound=0.000, batch=30
# 12: loss=1.333, reward_mean=0.000, reward_bound=0.000, batch=30
# 13: loss=1.325, reward_mean=0.050, reward_bound=0.000, batch=35
# 14: loss=1.320, reward_mean=0.010, reward_bound=0.000, batch=36
# 15: loss=1.315, reward_mean=0.010, reward_bound=0.000, batch=37
# 16: loss=1.314, reward_mean=0.050, reward_bound=0.000, batch=42
# 17: loss=1.309, reward_mean=0.020, reward_bound=0.000, batch=44
# 18: loss=1.304, reward_mean=0.030, reward_bound=0.000, batch=47
# 19: loss=1.299, reward_mean=0.040, reward_bound=0.000, batch=51
# 20: loss=1.296, reward_mean=0.060, reward_bound=0.000, batch=57
# 21: loss=1.292, reward_mean=0.040, reward_bound=0.000, batch=61
# 22: loss=1.290, reward_mean=0.040, reward_bound=0.000, batch=65
# 23: loss=1.289, reward_mean=0.040, reward_bound=0.000, batch=69
# 24: loss=1.284, reward_mean=0.040, reward_bound=0.000, batch=73
# 25: loss=1.280, reward_mean=0.060, reward_bound=0.000, batch=79
# 26: loss=1.279, reward_mean=0.050, reward_bound=0.000, batch=84
# 27: loss=1.273, reward_mean=0.050, reward_bound=0.000, batch=89
# 28: loss=1.270, reward_mean=0.050, reward_bound=0.000, batch=94
# 29: loss=1.265, reward_mean=0.020, reward_bound=0.000, batch=96
# 30: loss=1.262, reward_mean=0.060, reward_bound=0.000, batch=102
# 31: loss=1.257, reward_mean=0.050, reward_bound=0.000, batch=107
# 32: loss=1.253, reward_mean=0.060, reward_bound=0.000, batch=113
# 33: loss=1.249, reward_mean=0.040, reward_bound=0.000, batch=117
# 34: loss=1.250, reward_mean=0.050, reward_bound=0.000, batch=122
# 35: loss=1.245, reward_mean=0.060, reward_bound=0.000, batch=128
# 36: loss=1.240, reward_mean=0.090, reward_bound=0.000, batch=137
# 37: loss=1.236, reward_mean=0.050, reward_bound=0.000, batch=142
# 38: loss=1.229, reward_mean=0.070, reward_bound=0.000, batch=149
# 39: loss=1.226, reward_mean=0.070, reward_bound=0.000, batch=156
# 40: loss=1.221, reward_mean=0.080, reward_bound=0.000, batch=164
# 41: loss=1.215, reward_mean=0.130, reward_bound=0.000, batch=177
# 42: loss=1.211, reward_mean=0.100, reward_bound=0.000, batch=187
# 43: loss=1.206, reward_mean=0.040, reward_bound=0.000, batch=191
# 44: loss=1.203, reward_mean=0.100, reward_bound=0.000, batch=201
# 45: loss=1.200, reward_mean=0.040, reward_bound=0.000, batch=205
# 46: loss=1.188, reward_mean=0.110, reward_bound=0.053, batch=213
# 47: loss=1.178, reward_mean=0.110, reward_bound=0.105, batch=219
# 48: loss=1.175, reward_mean=0.070, reward_bound=0.114, batch=223
# 49: loss=1.150, reward_mean=0.180, reward_bound=0.167, batch=217
# 50: loss=1.137, reward_mean=0.070, reward_bound=0.185, batch=211
# 51: loss=1.122, reward_mean=0.180, reward_bound=0.206, batch=213
# 52: loss=1.101, reward_mean=0.130, reward_bound=0.229, batch=206
# 53: loss=1.081, reward_mean=0.130, reward_bound=0.254, batch=196
# 54: loss=1.084, reward_mean=0.110, reward_bound=0.044, batch=207
# 55: loss=1.068, reward_mean=0.190, reward_bound=0.277, batch=215
# 56: loss=1.048, reward_mean=0.220, reward_bound=0.282, batch=209
# 57: loss=1.014, reward_mean=0.160, reward_bound=0.314, batch=185
# 58: loss=1.009, reward_mean=0.120, reward_bound=0.000, batch=197
# 59: loss=1.002, reward_mean=0.150, reward_bound=0.206, batch=207
# 60: loss=0.992, reward_mean=0.150, reward_bound=0.308, batch=215
# 61: loss=0.957, reward_mean=0.220, reward_bound=0.349, batch=180
# 62: loss=0.949, reward_mean=0.180, reward_bound=0.254, batch=194
# 63: loss=0.943, reward_mean=0.220, reward_bound=0.345, batch=206
# 64: loss=0.931, reward_mean=0.170, reward_bound=0.349, batch=211
# 65: loss=0.875, reward_mean=0.180, reward_bound=0.387, batch=162
# 66: loss=0.870, reward_mean=0.250, reward_bound=0.314, batch=181
# 67: loss=0.865, reward_mean=0.240, reward_bound=0.314, batch=196
# 68: loss=0.848, reward_mean=0.260, reward_bound=0.387, batch=195
# 69: loss=0.839, reward_mean=0.250, reward_bound=0.387, batch=205
# 70: loss=0.771, reward_mean=0.220, reward_bound=0.430, batch=135
# 71: loss=0.796, reward_mean=0.190, reward_bound=0.000, batch=154
# 72: loss=0.792, reward_mean=0.290, reward_bound=0.229, batch=177
# 73: loss=0.770, reward_mean=0.240, reward_bound=0.314, batch=191
# 74: loss=0.742, reward_mean=0.320, reward_bound=0.387, batch=194
# 75: loss=0.741, reward_mean=0.190, reward_bound=0.384, batch=206
# 76: loss=0.704, reward_mean=0.330, reward_bound=0.430, batch=196
# 77: loss=0.693, reward_mean=0.310, reward_bound=0.430, batch=205
# 78: loss=0.601, reward_mean=0.330, reward_bound=0.478, batch=101
# 79: loss=0.683, reward_mean=0.350, reward_bound=0.000, batch=136
# 80: loss=0.651, reward_mean=0.410, reward_bound=0.314, batch=161
# 81: loss=0.631, reward_mean=0.340, reward_bound=0.349, batch=182
# 82: loss=0.592, reward_mean=0.400, reward_bound=0.430, batch=177
# 83: loss=0.542, reward_mean=0.320, reward_bound=0.478, batch=150
# 84: loss=0.558, reward_mean=0.310, reward_bound=0.376, batch=175
# 85: loss=0.532, reward_mean=0.380, reward_bound=0.430, batch=189
# 86: loss=0.527, reward_mean=0.430, reward_bound=0.478, batch=210
# 87: loss=0.498, reward_mean=0.460, reward_bound=0.478, batch=208
# 89: loss=0.735, reward_mean=0.420, reward_bound=0.000, batch=42
# 90: loss=0.737, reward_mean=0.450, reward_bound=0.000, batch=87
# 91: loss=0.739, reward_mean=0.380, reward_bound=0.000, batch=125
# 92: loss=0.699, reward_mean=0.340, reward_bound=0.282, batch=153
# 93: loss=0.611, reward_mean=0.590, reward_bound=0.387, batch=168
# 94: loss=0.528, reward_mean=0.420, reward_bound=0.430, batch=156
# 95: loss=0.441, reward_mean=0.430, reward_bound=0.478, batch=115
# 96: loss=0.449, reward_mean=0.460, reward_bound=0.430, batch=145
# 97: loss=0.426, reward_mean=0.580, reward_bound=0.478, batch=160
# 98: loss=0.420, reward_mean=0.390, reward_bound=0.478, batch=181
# 100: loss=0.601, reward_mean=0.510, reward_bound=0.000, batch=51
# 101: loss=0.642, reward_mean=0.480, reward_bound=0.000, batch=99
# 102: loss=0.533, reward_mean=0.590, reward_bound=0.387, batch=132
# 103: loss=0.470, reward_mean=0.590, reward_bound=0.430, batch=152
# 104: loss=0.386, reward_mean=0.620, reward_bound=0.478, batch=134
# 105: loss=0.380, reward_mean=0.640, reward_bound=0.478, batch=162
# 107: loss=0.588, reward_mean=0.530, reward_bound=0.000, batch=53
# 108: loss=0.524, reward_mean=0.680, reward_bound=0.387, batch=106
# 109: loss=0.451, reward_mean=0.580, reward_bound=0.430, batch=127
# 110: loss=0.365, reward_mean=0.650, reward_bound=0.478, batch=120
# 112: loss=0.545, reward_mean=0.530, reward_bound=0.000, batch=53
# 113: loss=0.495, reward_mean=0.610, reward_bound=0.387, batch=105
# 114: loss=0.348, reward_mean=0.720, reward_bound=0.478, batch=111
# 115: loss=0.345, reward_mean=0.670, reward_bound=0.478, batch=142
# 117: loss=0.469, reward_mean=0.710, reward_bound=0.387, batch=68
# 118: loss=0.441, reward_mean=0.640, reward_bound=0.430, batch=115
# 119: loss=0.331, reward_mean=0.700, reward_bound=0.478, batch=113
# 121: loss=0.492, reward_mean=0.590, reward_bound=0.000, batch=59
# 122: loss=0.408, reward_mean=0.710, reward_bound=0.430, batch=108
# 123: loss=0.407, reward_mean=0.690, reward_bound=0.478, batch=167
# 124: loss=0.314, reward_mean=0.790, reward_bound=0.478, batch=176
# 126: loss=0.492, reward_mean=0.670, reward_bound=0.000, batch=67
# 127: loss=0.307, reward_mean=0.750, reward_bound=0.478, batch=80
# 128: loss=0.303, reward_mean=0.680, reward_bound=0.478, batch=123
# 130: loss=0.393, reward_mean=0.720, reward_bound=0.387, batch=69
# 131: loss=0.293, reward_mean=0.760, reward_bound=0.478, batch=102
# 133: loss=0.373, reward_mean=0.760, reward_bound=0.464, batch=70
# 134: loss=0.295, reward_mean=0.750, reward_bound=0.478, batch=103
# 136: loss=0.415, reward_mean=0.720, reward_bound=0.387, batch=69
# 137: loss=0.286, reward_mean=0.690, reward_bound=0.478, batch=93
# 139: loss=0.342, reward_mean=0.780, reward_bound=0.478, batch=72
# 141: loss=0.356, reward_mean=0.750, reward_bound=0.430, batch=68
# 142: loss=0.276, reward_mean=0.790, reward_bound=0.478, batch=107
# 144: loss=0.328, reward_mean=0.880, reward_bound=0.478, batch=78
# Solved!
